# %% [markdown]
# ## 实验介绍

# %% [markdown]
# ### 1. 实验内容

# %% [markdown]
# 本实验介绍如何使用SVM算法解决手写识别问题，并介绍如何使用sklearn库创建svm模型。

# %% [markdown]
# ### 2. 实验目标

# %% [markdown]
# 通过本实验掌握SVM算法如何应用。

# %% [markdown]
# ### 3. 实验知识点

# %% [markdown]
# SVM支持向量机原理

# %% [markdown]
# ### 4. 实验环境

# %% [markdown]
# python 3.6.5

# %% [markdown]
# ### 5. 预备知识

# %% [markdown]
# 概率论与数理统计
# Linux命令基本操作
# Python编程基础

# %% [markdown]
# ## 准备工作

# %% [markdown]
# 点击屏幕右上方的下载实验数据模块，选择下载svm_hand_digits.tgz到指定目录下，然后再依次选择点击上方的File->Open->Upload,上传刚才下载的数据集压缩包，再使用如下命令解压：

# %%
# !tar -zxvf svm_hand_digits.tgz
# Out:
# svm_hand_digits/
# svm_hand_digits/testDigits/
# svm_hand_digits/testDigits/0_0.txt
# svm_hand_digits/testDigits/0_1.txt
# svm_hand_digits/testDigits/0_10.txt
# svm_hand_digits/testDigits/0_11.txt
# svm_hand_digits/testDigits/0_12.txt
# svm_hand_digits/testDigits/0_13.txt
# svm_hand_digits/testDigits/0_14.txt
# svm_hand_digits/testDigits/0_15.txt
# svm_hand_digits/testDigits/0_16.txt
# svm_hand_digits/testDigits/0_17.txt
# svm_hand_digits/testDigits/0_18.txt
# svm_hand_digits/testDigits/0_19.txt
# svm_hand_digits/testDigits/0_2.txt
# svm_hand_digits/testDigits/0_20.txt
# svm_hand_digits/testDigits/0_21.txt
# svm_hand_digits/testDigits/0_22.txt
# svm_hand_digits/testDigits/0_23.txt
# svm_hand_digits/testDigits/0_24.txt
# svm_hand_digits/testDigits/0_25.txt
# svm_hand_digits/testDigits/0_26.txt
# svm_hand_digits/testDigits/0_27.txt
# svm_hand_digits/testDigits/0_28.txt
# svm_hand_digits/testDigits/0_29.txt
# svm_hand_digits/testDigits/0_3.txt
# svm_hand_digits/testDigits/0_30.txt
# svm_hand_digits/testDigits/0_31.txt
# svm_hand_digits/testDigits/0_32.txt
# svm_hand_digits/testDigits/0_33.txt
# svm_hand_digits/testDigits/0_34.txt
# svm_hand_digits/testDigits/0_35.txt
# svm_hand_digits/testDigits/0_36.txt
# svm_hand_digits/testDigits/0_37.txt
# svm_hand_digits/testDigits/0_38.txt
# svm_hand_digits/testDigits/0_39.txt
# svm_hand_digits/testDigits/0_4.txt
# svm_hand_digits/testDigits/0_40.txt
# svm_hand_digits/testDigits/0_41.txt
# svm_hand_digits/testDigits/0_42.txt
# svm_hand_digits/testDigits/0_43.txt
# svm_hand_digits/testDigits/0_44.txt
# svm_hand_digits/testDigits/0_45.txt
# svm_hand_digits/testDigits/0_46.txt
# svm_hand_digits/testDigits/0_47.txt
# svm_hand_digits/testDigits/0_48.txt
# svm_hand_digits/testDigits/0_49.txt
# svm_hand_digits/testDigits/0_5.txt
# svm_hand_digits/testDigits/0_50.txt
# svm_hand_digits/testDigits/0_51.txt
# svm_hand_digits/testDigits/0_52.txt
# svm_hand_digits/testDigits/0_53.txt
# svm_hand_digits/testDigits/0_54.txt
# svm_hand_digits/testDigits/0_55.txt
# svm_hand_digits/testDigits/0_56.txt
# svm_hand_digits/testDigits/0_57.txt
# svm_hand_digits/testDigits/0_58.txt
# svm_hand_digits/testDigits/0_59.txt
# svm_hand_digits/testDigits/0_6.txt
# svm_hand_digits/testDigits/0_60.txt
# svm_hand_digits/testDigits/0_61.txt
# svm_hand_digits/testDigits/0_62.txt
# svm_hand_digits/testDigits/0_63.txt
# svm_hand_digits/testDigits/0_64.txt
# svm_hand_digits/testDigits/0_65.txt
# svm_hand_digits/testDigits/0_66.txt
# svm_hand_digits/testDigits/0_67.txt
# svm_hand_digits/testDigits/0_68.txt
# svm_hand_digits/testDigits/0_69.txt
# svm_hand_digits/testDigits/0_7.txt
# svm_hand_digits/testDigits/0_70.txt
# svm_hand_digits/testDigits/0_71.txt
# svm_hand_digits/testDigits/0_72.txt
# svm_hand_digits/testDigits/0_73.txt
# svm_hand_digits/testDigits/0_74.txt
# svm_hand_digits/testDigits/0_75.txt
# svm_hand_digits/testDigits/0_76.txt
# svm_hand_digits/testDigits/0_77.txt
# svm_hand_digits/testDigits/0_78.txt
# svm_hand_digits/testDigits/0_79.txt
# svm_hand_digits/testDigits/0_8.txt
# svm_hand_digits/testDigits/0_80.txt
# svm_hand_digits/testDigits/0_81.txt
# svm_hand_digits/testDigits/0_82.txt
# svm_hand_digits/testDigits/0_83.txt
# svm_hand_digits/testDigits/0_84.txt
# svm_hand_digits/testDigits/0_85.txt
# svm_hand_digits/testDigits/0_86.txt
# svm_hand_digits/testDigits/0_9.txt
# svm_hand_digits/testDigits/1_0.txt
# svm_hand_digits/testDigits/1_1.txt
# svm_hand_digits/testDigits/1_10.txt
# svm_hand_digits/testDigits/1_11.txt
# svm_hand_digits/testDigits/1_12.txt
# svm_hand_digits/testDigits/1_13.txt
# svm_hand_digits/testDigits/1_14.txt
# svm_hand_digits/testDigits/1_15.txt
# svm_hand_digits/testDigits/1_16.txt
# svm_hand_digits/testDigits/1_17.txt
# svm_hand_digits/testDigits/1_18.txt
# svm_hand_digits/testDigits/1_19.txt
# svm_hand_digits/testDigits/1_2.txt
# svm_hand_digits/testDigits/1_20.txt
# svm_hand_digits/testDigits/1_21.txt
# svm_hand_digits/testDigits/1_22.txt
# svm_hand_digits/testDigits/1_23.txt
# svm_hand_digits/testDigits/1_24.txt
# svm_hand_digits/testDigits/1_25.txt
# svm_hand_digits/testDigits/1_26.txt
# svm_hand_digits/testDigits/1_27.txt
# svm_hand_digits/testDigits/1_28.txt
# svm_hand_digits/testDigits/1_29.txt
# svm_hand_digits/testDigits/1_3.txt
# svm_hand_digits/testDigits/1_30.txt
# svm_hand_digits/testDigits/1_31.txt
# svm_hand_digits/testDigits/1_32.txt
# svm_hand_digits/testDigits/1_33.txt
# svm_hand_digits/testDigits/1_34.txt
# svm_hand_digits/testDigits/1_35.txt
# svm_hand_digits/testDigits/1_36.txt
# svm_hand_digits/testDigits/1_37.txt
# svm_hand_digits/testDigits/1_38.txt
# svm_hand_digits/testDigits/1_39.txt
# svm_hand_digits/testDigits/1_4.txt
# svm_hand_digits/testDigits/1_40.txt
# svm_hand_digits/testDigits/1_41.txt
# svm_hand_digits/testDigits/1_42.txt
# svm_hand_digits/testDigits/1_43.txt
# svm_hand_digits/testDigits/1_44.txt
# svm_hand_digits/testDigits/1_45.txt
# svm_hand_digits/testDigits/1_46.txt
# svm_hand_digits/testDigits/1_47.txt
# svm_hand_digits/testDigits/1_48.txt
# svm_hand_digits/testDigits/1_49.txt
# svm_hand_digits/testDigits/1_5.txt
# svm_hand_digits/testDigits/1_50.txt
# svm_hand_digits/testDigits/1_51.txt
# svm_hand_digits/testDigits/1_52.txt
# svm_hand_digits/testDigits/1_53.txt
# svm_hand_digits/testDigits/1_54.txt
# svm_hand_digits/testDigits/1_55.txt
# svm_hand_digits/testDigits/1_56.txt
# svm_hand_digits/testDigits/1_57.txt
# svm_hand_digits/testDigits/1_58.txt
# svm_hand_digits/testDigits/1_59.txt
# svm_hand_digits/testDigits/1_6.txt
# svm_hand_digits/testDigits/1_60.txt
# svm_hand_digits/testDigits/1_61.txt
# svm_hand_digits/testDigits/1_62.txt
# svm_hand_digits/testDigits/1_63.txt
# svm_hand_digits/testDigits/1_64.txt
# svm_hand_digits/testDigits/1_65.txt
# svm_hand_digits/testDigits/1_66.txt
# svm_hand_digits/testDigits/1_67.txt
# svm_hand_digits/testDigits/1_68.txt
# svm_hand_digits/testDigits/1_69.txt
# svm_hand_digits/testDigits/1_7.txt
# svm_hand_digits/testDigits/1_70.txt
# svm_hand_digits/testDigits/1_71.txt
# svm_hand_digits/testDigits/1_72.txt
# svm_hand_digits/testDigits/1_73.txt
# svm_hand_digits/testDigits/1_74.txt
# svm_hand_digits/testDigits/1_75.txt
# svm_hand_digits/testDigits/1_76.txt
# svm_hand_digits/testDigits/1_77.txt
# svm_hand_digits/testDigits/1_78.txt
# svm_hand_digits/testDigits/1_79.txt
# svm_hand_digits/testDigits/1_8.txt
# svm_hand_digits/testDigits/1_80.txt
# svm_hand_digits/testDigits/1_81.txt
# svm_hand_digits/testDigits/1_82.txt
# svm_hand_digits/testDigits/1_83.txt
# svm_hand_digits/testDigits/1_84.txt
# svm_hand_digits/testDigits/1_85.txt
# svm_hand_digits/testDigits/1_86.txt
# svm_hand_digits/testDigits/1_87.txt
# svm_hand_digits/testDigits/1_88.txt
# svm_hand_digits/testDigits/1_89.txt
# svm_hand_digits/testDigits/1_9.txt
# svm_hand_digits/testDigits/1_90.txt
# svm_hand_digits/testDigits/1_91.txt
# svm_hand_digits/testDigits/1_92.txt
# svm_hand_digits/testDigits/1_93.txt
# svm_hand_digits/testDigits/1_94.txt
# svm_hand_digits/testDigits/1_95.txt
# svm_hand_digits/testDigits/1_96.txt
# svm_hand_digits/testDigits/2_0.txt
# svm_hand_digits/testDigits/2_1.txt
# svm_hand_digits/testDigits/2_10.txt
# svm_hand_digits/testDigits/2_11.txt
# svm_hand_digits/testDigits/2_12.txt
# svm_hand_digits/testDigits/2_13.txt
# svm_hand_digits/testDigits/2_14.txt
# svm_hand_digits/testDigits/2_15.txt
# svm_hand_digits/testDigits/2_16.txt
# svm_hand_digits/testDigits/2_17.txt
# svm_hand_digits/testDigits/2_18.txt
# svm_hand_digits/testDigits/2_19.txt
# svm_hand_digits/testDigits/2_2.txt
# svm_hand_digits/testDigits/2_20.txt
# svm_hand_digits/testDigits/2_21.txt
# svm_hand_digits/testDigits/2_22.txt
# svm_hand_digits/testDigits/2_23.txt
# svm_hand_digits/testDigits/2_24.txt
# svm_hand_digits/testDigits/2_25.txt
# svm_hand_digits/testDigits/2_26.txt
# svm_hand_digits/testDigits/2_27.txt
# svm_hand_digits/testDigits/2_28.txt
# svm_hand_digits/testDigits/2_29.txt
# svm_hand_digits/testDigits/2_3.txt
# svm_hand_digits/testDigits/2_30.txt
# svm_hand_digits/testDigits/2_31.txt
# svm_hand_digits/testDigits/2_32.txt
# svm_hand_digits/testDigits/2_33.txt
# svm_hand_digits/testDigits/2_34.txt
# svm_hand_digits/testDigits/2_35.txt
# svm_hand_digits/testDigits/2_36.txt
# svm_hand_digits/testDigits/2_37.txt
# svm_hand_digits/testDigits/2_38.txt
# svm_hand_digits/testDigits/2_39.txt
# svm_hand_digits/testDigits/2_4.txt
# svm_hand_digits/testDigits/2_40.txt
# svm_hand_digits/testDigits/2_41.txt
# svm_hand_digits/testDigits/2_42.txt
# svm_hand_digits/testDigits/2_43.txt
# svm_hand_digits/testDigits/2_44.txt
# svm_hand_digits/testDigits/2_45.txt
# svm_hand_digits/testDigits/2_46.txt
# svm_hand_digits/testDigits/2_47.txt
# svm_hand_digits/testDigits/2_48.txt
# svm_hand_digits/testDigits/2_49.txt
# svm_hand_digits/testDigits/2_5.txt
# svm_hand_digits/testDigits/2_50.txt
# svm_hand_digits/testDigits/2_51.txt
# svm_hand_digits/testDigits/2_52.txt
# svm_hand_digits/testDigits/2_53.txt
# svm_hand_digits/testDigits/2_54.txt
# svm_hand_digits/testDigits/2_55.txt
# svm_hand_digits/testDigits/2_56.txt
# svm_hand_digits/testDigits/2_57.txt
# svm_hand_digits/testDigits/2_58.txt
# svm_hand_digits/testDigits/2_59.txt
# svm_hand_digits/testDigits/2_6.txt
# svm_hand_digits/testDigits/2_60.txt
# svm_hand_digits/testDigits/2_61.txt
# svm_hand_digits/testDigits/2_62.txt
# svm_hand_digits/testDigits/2_63.txt
# svm_hand_digits/testDigits/2_64.txt
# svm_hand_digits/testDigits/2_65.txt
# svm_hand_digits/testDigits/2_66.txt
# svm_hand_digits/testDigits/2_67.txt
# svm_hand_digits/testDigits/2_68.txt
# svm_hand_digits/testDigits/2_69.txt
# svm_hand_digits/testDigits/2_7.txt
# svm_hand_digits/testDigits/2_70.txt
# svm_hand_digits/testDigits/2_71.txt
# svm_hand_digits/testDigits/2_72.txt
# svm_hand_digits/testDigits/2_73.txt
# svm_hand_digits/testDigits/2_74.txt
# svm_hand_digits/testDigits/2_75.txt
# svm_hand_digits/testDigits/2_76.txt
# svm_hand_digits/testDigits/2_77.txt
# svm_hand_digits/testDigits/2_78.txt
# svm_hand_digits/testDigits/2_79.txt
# svm_hand_digits/testDigits/2_8.txt
# svm_hand_digits/testDigits/2_80.txt
# svm_hand_digits/testDigits/2_81.txt
# svm_hand_digits/testDigits/2_82.txt
# svm_hand_digits/testDigits/2_83.txt
# svm_hand_digits/testDigits/2_84.txt
# svm_hand_digits/testDigits/2_85.txt
# svm_hand_digits/testDigits/2_86.txt
# svm_hand_digits/testDigits/2_87.txt
# svm_hand_digits/testDigits/2_88.txt
# svm_hand_digits/testDigits/2_89.txt
# svm_hand_digits/testDigits/2_9.txt
# svm_hand_digits/testDigits/2_90.txt
# svm_hand_digits/testDigits/2_91.txt
# svm_hand_digits/testDigits/3_0.txt
# svm_hand_digits/testDigits/3_1.txt
# svm_hand_digits/testDigits/3_10.txt
# svm_hand_digits/testDigits/3_11.txt
# svm_hand_digits/testDigits/3_12.txt
# svm_hand_digits/testDigits/3_13.txt
# svm_hand_digits/testDigits/3_14.txt
# svm_hand_digits/testDigits/3_15.txt
# svm_hand_digits/testDigits/3_16.txt
# svm_hand_digits/testDigits/3_17.txt
# svm_hand_digits/testDigits/3_18.txt
# svm_hand_digits/testDigits/3_19.txt
# svm_hand_digits/testDigits/3_2.txt
# svm_hand_digits/testDigits/3_20.txt
# svm_hand_digits/testDigits/3_21.txt
# svm_hand_digits/testDigits/3_22.txt
# svm_hand_digits/testDigits/3_23.txt
# svm_hand_digits/testDigits/3_24.txt
# svm_hand_digits/testDigits/3_25.txt
# svm_hand_digits/testDigits/3_26.txt
# svm_hand_digits/testDigits/3_27.txt
# svm_hand_digits/testDigits/3_28.txt
# svm_hand_digits/testDigits/3_29.txt
# svm_hand_digits/testDigits/3_3.txt
# svm_hand_digits/testDigits/3_30.txt
# svm_hand_digits/testDigits/3_31.txt
# svm_hand_digits/testDigits/3_32.txt
# svm_hand_digits/testDigits/3_33.txt
# svm_hand_digits/testDigits/3_34.txt
# svm_hand_digits/testDigits/3_35.txt
# svm_hand_digits/testDigits/3_36.txt
# svm_hand_digits/testDigits/3_37.txt
# svm_hand_digits/testDigits/3_38.txt
# svm_hand_digits/testDigits/3_39.txt
# svm_hand_digits/testDigits/3_4.txt
# svm_hand_digits/testDigits/3_40.txt
# svm_hand_digits/testDigits/3_41.txt
# svm_hand_digits/testDigits/3_42.txt
# svm_hand_digits/testDigits/3_43.txt
# svm_hand_digits/testDigits/3_44.txt
# svm_hand_digits/testDigits/3_45.txt
# svm_hand_digits/testDigits/3_46.txt
# svm_hand_digits/testDigits/3_47.txt
# svm_hand_digits/testDigits/3_48.txt
# svm_hand_digits/testDigits/3_49.txt
# svm_hand_digits/testDigits/3_5.txt
# svm_hand_digits/testDigits/3_50.txt
# svm_hand_digits/testDigits/3_51.txt
# svm_hand_digits/testDigits/3_52.txt
# svm_hand_digits/testDigits/3_53.txt
# svm_hand_digits/testDigits/3_54.txt
# svm_hand_digits/testDigits/3_55.txt
# svm_hand_digits/testDigits/3_56.txt
# svm_hand_digits/testDigits/3_57.txt
# svm_hand_digits/testDigits/3_58.txt
# svm_hand_digits/testDigits/3_59.txt
# svm_hand_digits/testDigits/3_6.txt
# svm_hand_digits/testDigits/3_60.txt
# svm_hand_digits/testDigits/3_61.txt
# svm_hand_digits/testDigits/3_62.txt
# svm_hand_digits/testDigits/3_63.txt
# svm_hand_digits/testDigits/3_64.txt
# svm_hand_digits/testDigits/3_65.txt
# svm_hand_digits/testDigits/3_66.txt
# svm_hand_digits/testDigits/3_67.txt
# svm_hand_digits/testDigits/3_68.txt
# svm_hand_digits/testDigits/3_69.txt
# svm_hand_digits/testDigits/3_7.txt
# svm_hand_digits/testDigits/3_70.txt
# svm_hand_digits/testDigits/3_71.txt
# svm_hand_digits/testDigits/3_72.txt
# svm_hand_digits/testDigits/3_73.txt
# svm_hand_digits/testDigits/3_74.txt
# svm_hand_digits/testDigits/3_75.txt
# svm_hand_digits/testDigits/3_76.txt
# svm_hand_digits/testDigits/3_77.txt
# svm_hand_digits/testDigits/3_78.txt
# svm_hand_digits/testDigits/3_79.txt
# svm_hand_digits/testDigits/3_8.txt
# svm_hand_digits/testDigits/3_80.txt
# svm_hand_digits/testDigits/3_81.txt
# svm_hand_digits/testDigits/3_82.txt
# svm_hand_digits/testDigits/3_83.txt
# svm_hand_digits/testDigits/3_84.txt
# svm_hand_digits/testDigits/3_9.txt
# svm_hand_digits/testDigits/4_0.txt
# svm_hand_digits/testDigits/4_1.txt
# svm_hand_digits/testDigits/4_10.txt
# svm_hand_digits/testDigits/4_100.txt
# svm_hand_digits/testDigits/4_101.txt
# svm_hand_digits/testDigits/4_102.txt
# svm_hand_digits/testDigits/4_103.txt
# svm_hand_digits/testDigits/4_104.txt
# svm_hand_digits/testDigits/4_105.txt
# svm_hand_digits/testDigits/4_106.txt
# svm_hand_digits/testDigits/4_107.txt
# svm_hand_digits/testDigits/4_108.txt
# svm_hand_digits/testDigits/4_109.txt
# svm_hand_digits/testDigits/4_11.txt
# svm_hand_digits/testDigits/4_110.txt
# svm_hand_digits/testDigits/4_111.txt
# svm_hand_digits/testDigits/4_112.txt
# svm_hand_digits/testDigits/4_113.txt
# svm_hand_digits/testDigits/4_12.txt
# svm_hand_digits/testDigits/4_13.txt
# svm_hand_digits/testDigits/4_14.txt
# svm_hand_digits/testDigits/4_15.txt
# svm_hand_digits/testDigits/4_16.txt
# svm_hand_digits/testDigits/4_17.txt
# svm_hand_digits/testDigits/4_18.txt
# svm_hand_digits/testDigits/4_19.txt
# svm_hand_digits/testDigits/4_2.txt
# svm_hand_digits/testDigits/4_20.txt
# svm_hand_digits/testDigits/4_21.txt
# svm_hand_digits/testDigits/4_22.txt
# svm_hand_digits/testDigits/4_23.txt
# svm_hand_digits/testDigits/4_24.txt
# svm_hand_digits/testDigits/4_25.txt
# svm_hand_digits/testDigits/4_26.txt
# svm_hand_digits/testDigits/4_27.txt
# svm_hand_digits/testDigits/4_28.txt
# svm_hand_digits/testDigits/4_29.txt
# svm_hand_digits/testDigits/4_3.txt
# svm_hand_digits/testDigits/4_30.txt
# svm_hand_digits/testDigits/4_31.txt
# svm_hand_digits/testDigits/4_32.txt
# svm_hand_digits/testDigits/4_33.txt
# svm_hand_digits/testDigits/4_34.txt
# svm_hand_digits/testDigits/4_35.txt
# svm_hand_digits/testDigits/4_36.txt
# svm_hand_digits/testDigits/4_37.txt
# svm_hand_digits/testDigits/4_38.txt
# svm_hand_digits/testDigits/4_39.txt
# svm_hand_digits/testDigits/4_4.txt
# svm_hand_digits/testDigits/4_40.txt
# svm_hand_digits/testDigits/4_41.txt
# svm_hand_digits/testDigits/4_42.txt
# svm_hand_digits/testDigits/4_43.txt
# svm_hand_digits/testDigits/4_44.txt
# svm_hand_digits/testDigits/4_45.txt
# svm_hand_digits/testDigits/4_46.txt
# svm_hand_digits/testDigits/4_47.txt
# svm_hand_digits/testDigits/4_48.txt
# svm_hand_digits/testDigits/4_49.txt
# svm_hand_digits/testDigits/4_5.txt
# svm_hand_digits/testDigits/4_50.txt
# svm_hand_digits/testDigits/4_51.txt
# svm_hand_digits/testDigits/4_52.txt
# svm_hand_digits/testDigits/4_53.txt
# svm_hand_digits/testDigits/4_54.txt
# svm_hand_digits/testDigits/4_55.txt
# svm_hand_digits/testDigits/4_56.txt
# svm_hand_digits/testDigits/4_57.txt
# svm_hand_digits/testDigits/4_58.txt
# svm_hand_digits/testDigits/4_59.txt
# svm_hand_digits/testDigits/4_6.txt
# svm_hand_digits/testDigits/4_60.txt
# svm_hand_digits/testDigits/4_61.txt
# svm_hand_digits/testDigits/4_62.txt
# svm_hand_digits/testDigits/4_63.txt
# svm_hand_digits/testDigits/4_64.txt
# svm_hand_digits/testDigits/4_65.txt
# svm_hand_digits/testDigits/4_66.txt
# svm_hand_digits/testDigits/4_67.txt
# svm_hand_digits/testDigits/4_68.txt
# svm_hand_digits/testDigits/4_69.txt
# svm_hand_digits/testDigits/4_7.txt
# svm_hand_digits/testDigits/4_70.txt
# svm_hand_digits/testDigits/4_71.txt
# svm_hand_digits/testDigits/4_72.txt
# svm_hand_digits/testDigits/4_73.txt
# svm_hand_digits/testDigits/4_74.txt
# svm_hand_digits/testDigits/4_75.txt
# svm_hand_digits/testDigits/4_76.txt
# svm_hand_digits/testDigits/4_77.txt
# svm_hand_digits/testDigits/4_78.txt
# svm_hand_digits/testDigits/4_79.txt
# svm_hand_digits/testDigits/4_8.txt
# svm_hand_digits/testDigits/4_80.txt
# svm_hand_digits/testDigits/4_81.txt
# svm_hand_digits/testDigits/4_82.txt
# svm_hand_digits/testDigits/4_83.txt
# svm_hand_digits/testDigits/4_84.txt
# svm_hand_digits/testDigits/4_85.txt
# svm_hand_digits/testDigits/4_86.txt
# svm_hand_digits/testDigits/4_87.txt
# svm_hand_digits/testDigits/4_88.txt
# svm_hand_digits/testDigits/4_89.txt
# svm_hand_digits/testDigits/4_9.txt
# svm_hand_digits/testDigits/4_90.txt
# svm_hand_digits/testDigits/4_91.txt
# svm_hand_digits/testDigits/4_92.txt
# svm_hand_digits/testDigits/4_93.txt
# svm_hand_digits/testDigits/4_94.txt
# svm_hand_digits/testDigits/4_95.txt
# svm_hand_digits/testDigits/4_96.txt
# svm_hand_digits/testDigits/4_97.txt
# svm_hand_digits/testDigits/4_98.txt
# svm_hand_digits/testDigits/4_99.txt
# svm_hand_digits/testDigits/5_0.txt
# svm_hand_digits/testDigits/5_1.txt
# svm_hand_digits/testDigits/5_10.txt
# svm_hand_digits/testDigits/5_100.txt
# svm_hand_digits/testDigits/5_101.txt
# svm_hand_digits/testDigits/5_102.txt
# svm_hand_digits/testDigits/5_103.txt
# svm_hand_digits/testDigits/5_104.txt
# svm_hand_digits/testDigits/5_105.txt
# svm_hand_digits/testDigits/5_106.txt
# svm_hand_digits/testDigits/5_107.txt
# svm_hand_digits/testDigits/5_11.txt
# svm_hand_digits/testDigits/5_12.txt
# svm_hand_digits/testDigits/5_13.txt
# svm_hand_digits/testDigits/5_14.txt
# svm_hand_digits/testDigits/5_15.txt
# svm_hand_digits/testDigits/5_16.txt
# svm_hand_digits/testDigits/5_17.txt
# svm_hand_digits/testDigits/5_18.txt
# svm_hand_digits/testDigits/5_19.txt
# svm_hand_digits/testDigits/5_2.txt
# svm_hand_digits/testDigits/5_20.txt
# svm_hand_digits/testDigits/5_21.txt
# svm_hand_digits/testDigits/5_22.txt
# svm_hand_digits/testDigits/5_23.txt
# svm_hand_digits/testDigits/5_24.txt
# svm_hand_digits/testDigits/5_25.txt
# svm_hand_digits/testDigits/5_26.txt
# svm_hand_digits/testDigits/5_27.txt
# svm_hand_digits/testDigits/5_28.txt
# svm_hand_digits/testDigits/5_29.txt
# svm_hand_digits/testDigits/5_3.txt
# svm_hand_digits/testDigits/5_30.txt
# svm_hand_digits/testDigits/5_31.txt
# svm_hand_digits/testDigits/5_32.txt
# svm_hand_digits/testDigits/5_33.txt
# svm_hand_digits/testDigits/5_34.txt
# svm_hand_digits/testDigits/5_35.txt
# svm_hand_digits/testDigits/5_36.txt
# svm_hand_digits/testDigits/5_37.txt
# svm_hand_digits/testDigits/5_38.txt
# svm_hand_digits/testDigits/5_39.txt
# svm_hand_digits/testDigits/5_4.txt
# svm_hand_digits/testDigits/5_40.txt
# svm_hand_digits/testDigits/5_41.txt
# svm_hand_digits/testDigits/5_42.txt
# svm_hand_digits/testDigits/5_43.txt
# svm_hand_digits/testDigits/5_44.txt
# svm_hand_digits/testDigits/5_45.txt
# svm_hand_digits/testDigits/5_46.txt
# svm_hand_digits/testDigits/5_47.txt
# svm_hand_digits/testDigits/5_48.txt
# svm_hand_digits/testDigits/5_49.txt
# svm_hand_digits/testDigits/5_5.txt
# svm_hand_digits/testDigits/5_50.txt
# svm_hand_digits/testDigits/5_51.txt
# svm_hand_digits/testDigits/5_52.txt
# svm_hand_digits/testDigits/5_53.txt
# svm_hand_digits/testDigits/5_54.txt
# svm_hand_digits/testDigits/5_55.txt
# svm_hand_digits/testDigits/5_56.txt
# svm_hand_digits/testDigits/5_57.txt
# svm_hand_digits/testDigits/5_58.txt
# svm_hand_digits/testDigits/5_59.txt
# svm_hand_digits/testDigits/5_6.txt
# svm_hand_digits/testDigits/5_60.txt
# svm_hand_digits/testDigits/5_61.txt
# svm_hand_digits/testDigits/5_62.txt
# svm_hand_digits/testDigits/5_63.txt
# svm_hand_digits/testDigits/5_64.txt
# svm_hand_digits/testDigits/5_65.txt
# svm_hand_digits/testDigits/5_66.txt
# svm_hand_digits/testDigits/5_67.txt
# svm_hand_digits/testDigits/5_68.txt
# svm_hand_digits/testDigits/5_69.txt
# svm_hand_digits/testDigits/5_7.txt
# svm_hand_digits/testDigits/5_70.txt
# svm_hand_digits/testDigits/5_71.txt
# svm_hand_digits/testDigits/5_72.txt
# svm_hand_digits/testDigits/5_73.txt
# svm_hand_digits/testDigits/5_74.txt
# svm_hand_digits/testDigits/5_75.txt
# svm_hand_digits/testDigits/5_76.txt
# svm_hand_digits/testDigits/5_77.txt
# svm_hand_digits/testDigits/5_78.txt
# svm_hand_digits/testDigits/5_79.txt
# svm_hand_digits/testDigits/5_8.txt
# svm_hand_digits/testDigits/5_80.txt
# svm_hand_digits/testDigits/5_81.txt
# svm_hand_digits/testDigits/5_82.txt
# svm_hand_digits/testDigits/5_83.txt
# svm_hand_digits/testDigits/5_84.txt
# svm_hand_digits/testDigits/5_85.txt
# svm_hand_digits/testDigits/5_86.txt
# svm_hand_digits/testDigits/5_87.txt
# svm_hand_digits/testDigits/5_88.txt
# svm_hand_digits/testDigits/5_89.txt
# svm_hand_digits/testDigits/5_9.txt
# svm_hand_digits/testDigits/5_90.txt
# svm_hand_digits/testDigits/5_91.txt
# svm_hand_digits/testDigits/5_92.txt
# svm_hand_digits/testDigits/5_93.txt
# svm_hand_digits/testDigits/5_94.txt
# svm_hand_digits/testDigits/5_95.txt
# svm_hand_digits/testDigits/5_96.txt
# svm_hand_digits/testDigits/5_97.txt
# svm_hand_digits/testDigits/5_98.txt
# svm_hand_digits/testDigits/5_99.txt
# svm_hand_digits/testDigits/6_0.txt
# svm_hand_digits/testDigits/6_1.txt
# svm_hand_digits/testDigits/6_10.txt
# svm_hand_digits/testDigits/6_11.txt
# svm_hand_digits/testDigits/6_12.txt
# svm_hand_digits/testDigits/6_13.txt
# svm_hand_digits/testDigits/6_14.txt
# svm_hand_digits/testDigits/6_15.txt
# svm_hand_digits/testDigits/6_16.txt
# svm_hand_digits/testDigits/6_17.txt
# svm_hand_digits/testDigits/6_18.txt
# svm_hand_digits/testDigits/6_19.txt
# svm_hand_digits/testDigits/6_2.txt
# svm_hand_digits/testDigits/6_20.txt
# svm_hand_digits/testDigits/6_21.txt
# svm_hand_digits/testDigits/6_22.txt
# svm_hand_digits/testDigits/6_23.txt
# svm_hand_digits/testDigits/6_24.txt
# svm_hand_digits/testDigits/6_25.txt
# svm_hand_digits/testDigits/6_26.txt
# svm_hand_digits/testDigits/6_27.txt
# svm_hand_digits/testDigits/6_28.txt
# svm_hand_digits/testDigits/6_29.txt
# svm_hand_digits/testDigits/6_3.txt
# svm_hand_digits/testDigits/6_30.txt
# svm_hand_digits/testDigits/6_31.txt
# svm_hand_digits/testDigits/6_32.txt
# svm_hand_digits/testDigits/6_33.txt
# svm_hand_digits/testDigits/6_34.txt
# svm_hand_digits/testDigits/6_35.txt
# svm_hand_digits/testDigits/6_36.txt
# svm_hand_digits/testDigits/6_37.txt
# svm_hand_digits/testDigits/6_38.txt
# svm_hand_digits/testDigits/6_39.txt
# svm_hand_digits/testDigits/6_4.txt
# svm_hand_digits/testDigits/6_40.txt
# svm_hand_digits/testDigits/6_41.txt
# svm_hand_digits/testDigits/6_42.txt
# svm_hand_digits/testDigits/6_43.txt
# svm_hand_digits/testDigits/6_44.txt
# svm_hand_digits/testDigits/6_45.txt
# svm_hand_digits/testDigits/6_46.txt
# svm_hand_digits/testDigits/6_47.txt
# svm_hand_digits/testDigits/6_48.txt
# svm_hand_digits/testDigits/6_49.txt
# svm_hand_digits/testDigits/6_5.txt
# svm_hand_digits/testDigits/6_50.txt
# svm_hand_digits/testDigits/6_51.txt
# svm_hand_digits/testDigits/6_52.txt
# svm_hand_digits/testDigits/6_53.txt
# svm_hand_digits/testDigits/6_54.txt
# svm_hand_digits/testDigits/6_55.txt
# svm_hand_digits/testDigits/6_56.txt
# svm_hand_digits/testDigits/6_57.txt
# svm_hand_digits/testDigits/6_58.txt
# svm_hand_digits/testDigits/6_59.txt
# svm_hand_digits/testDigits/6_6.txt
# svm_hand_digits/testDigits/6_60.txt
# svm_hand_digits/testDigits/6_61.txt
# svm_hand_digits/testDigits/6_62.txt
# svm_hand_digits/testDigits/6_63.txt
# svm_hand_digits/testDigits/6_64.txt
# svm_hand_digits/testDigits/6_65.txt
# svm_hand_digits/testDigits/6_66.txt
# svm_hand_digits/testDigits/6_67.txt
# svm_hand_digits/testDigits/6_68.txt
# svm_hand_digits/testDigits/6_69.txt
# svm_hand_digits/testDigits/6_7.txt
# svm_hand_digits/testDigits/6_70.txt
# svm_hand_digits/testDigits/6_71.txt
# svm_hand_digits/testDigits/6_72.txt
# svm_hand_digits/testDigits/6_73.txt
# svm_hand_digits/testDigits/6_74.txt
# svm_hand_digits/testDigits/6_75.txt
# svm_hand_digits/testDigits/6_76.txt
# svm_hand_digits/testDigits/6_77.txt
# svm_hand_digits/testDigits/6_78.txt
# svm_hand_digits/testDigits/6_79.txt
# svm_hand_digits/testDigits/6_8.txt
# svm_hand_digits/testDigits/6_80.txt
# svm_hand_digits/testDigits/6_81.txt
# svm_hand_digits/testDigits/6_82.txt
# svm_hand_digits/testDigits/6_83.txt
# svm_hand_digits/testDigits/6_84.txt
# svm_hand_digits/testDigits/6_85.txt
# svm_hand_digits/testDigits/6_86.txt
# svm_hand_digits/testDigits/6_9.txt
# svm_hand_digits/testDigits/7_0.txt
# svm_hand_digits/testDigits/7_1.txt
# svm_hand_digits/testDigits/7_10.txt
# svm_hand_digits/testDigits/7_11.txt
# svm_hand_digits/testDigits/7_12.txt
# svm_hand_digits/testDigits/7_13.txt
# svm_hand_digits/testDigits/7_14.txt
# svm_hand_digits/testDigits/7_15.txt
# svm_hand_digits/testDigits/7_16.txt
# svm_hand_digits/testDigits/7_17.txt
# svm_hand_digits/testDigits/7_18.txt
# svm_hand_digits/testDigits/7_19.txt
# svm_hand_digits/testDigits/7_2.txt
# svm_hand_digits/testDigits/7_20.txt
# svm_hand_digits/testDigits/7_21.txt
# svm_hand_digits/testDigits/7_22.txt
# svm_hand_digits/testDigits/7_23.txt
# svm_hand_digits/testDigits/7_24.txt
# svm_hand_digits/testDigits/7_25.txt
# svm_hand_digits/testDigits/7_26.txt
# svm_hand_digits/testDigits/7_27.txt
# svm_hand_digits/testDigits/7_28.txt
# svm_hand_digits/testDigits/7_29.txt
# svm_hand_digits/testDigits/7_3.txt
# svm_hand_digits/testDigits/7_30.txt
# svm_hand_digits/testDigits/7_31.txt
# svm_hand_digits/testDigits/7_32.txt
# svm_hand_digits/testDigits/7_33.txt
# svm_hand_digits/testDigits/7_34.txt
# svm_hand_digits/testDigits/7_35.txt
# svm_hand_digits/testDigits/7_36.txt
# svm_hand_digits/testDigits/7_37.txt
# svm_hand_digits/testDigits/7_38.txt
# svm_hand_digits/testDigits/7_39.txt
# svm_hand_digits/testDigits/7_4.txt
# svm_hand_digits/testDigits/7_40.txt
# svm_hand_digits/testDigits/7_41.txt
# svm_hand_digits/testDigits/7_42.txt
# svm_hand_digits/testDigits/7_43.txt
# svm_hand_digits/testDigits/7_44.txt
# svm_hand_digits/testDigits/7_45.txt
# svm_hand_digits/testDigits/7_46.txt
# svm_hand_digits/testDigits/7_47.txt
# svm_hand_digits/testDigits/7_48.txt
# svm_hand_digits/testDigits/7_49.txt
# svm_hand_digits/testDigits/7_5.txt
# svm_hand_digits/testDigits/7_50.txt
# svm_hand_digits/testDigits/7_51.txt
# svm_hand_digits/testDigits/7_52.txt
# svm_hand_digits/testDigits/7_53.txt
# svm_hand_digits/testDigits/7_54.txt
# svm_hand_digits/testDigits/7_55.txt
# svm_hand_digits/testDigits/7_56.txt
# svm_hand_digits/testDigits/7_57.txt
# svm_hand_digits/testDigits/7_58.txt
# svm_hand_digits/testDigits/7_59.txt
# svm_hand_digits/testDigits/7_6.txt
# svm_hand_digits/testDigits/7_60.txt
# svm_hand_digits/testDigits/7_61.txt
# svm_hand_digits/testDigits/7_62.txt
# svm_hand_digits/testDigits/7_63.txt
# svm_hand_digits/testDigits/7_64.txt
# svm_hand_digits/testDigits/7_65.txt
# svm_hand_digits/testDigits/7_66.txt
# svm_hand_digits/testDigits/7_67.txt
# svm_hand_digits/testDigits/7_68.txt
# svm_hand_digits/testDigits/7_69.txt
# svm_hand_digits/testDigits/7_7.txt
# svm_hand_digits/testDigits/7_70.txt
# svm_hand_digits/testDigits/7_71.txt
# svm_hand_digits/testDigits/7_72.txt
# svm_hand_digits/testDigits/7_73.txt
# svm_hand_digits/testDigits/7_74.txt
# svm_hand_digits/testDigits/7_75.txt
# svm_hand_digits/testDigits/7_76.txt
# svm_hand_digits/testDigits/7_77.txt
# svm_hand_digits/testDigits/7_78.txt
# svm_hand_digits/testDigits/7_79.txt
# svm_hand_digits/testDigits/7_8.txt
# svm_hand_digits/testDigits/7_80.txt
# svm_hand_digits/testDigits/7_81.txt
# svm_hand_digits/testDigits/7_82.txt
# svm_hand_digits/testDigits/7_83.txt
# svm_hand_digits/testDigits/7_84.txt
# svm_hand_digits/testDigits/7_85.txt
# svm_hand_digits/testDigits/7_86.txt
# svm_hand_digits/testDigits/7_87.txt
# svm_hand_digits/testDigits/7_88.txt
# svm_hand_digits/testDigits/7_89.txt
# svm_hand_digits/testDigits/7_9.txt
# svm_hand_digits/testDigits/7_90.txt
# svm_hand_digits/testDigits/7_91.txt
# svm_hand_digits/testDigits/7_92.txt
# svm_hand_digits/testDigits/7_93.txt
# svm_hand_digits/testDigits/7_94.txt
# svm_hand_digits/testDigits/7_95.txt
# svm_hand_digits/testDigits/8_0.txt
# svm_hand_digits/testDigits/8_1.txt
# svm_hand_digits/testDigits/8_10.txt
# svm_hand_digits/testDigits/8_11.txt
# svm_hand_digits/testDigits/8_12.txt
# svm_hand_digits/testDigits/8_13.txt
# svm_hand_digits/testDigits/8_14.txt
# svm_hand_digits/testDigits/8_15.txt
# svm_hand_digits/testDigits/8_16.txt
# svm_hand_digits/testDigits/8_17.txt
# svm_hand_digits/testDigits/8_18.txt
# svm_hand_digits/testDigits/8_19.txt
# svm_hand_digits/testDigits/8_2.txt
# svm_hand_digits/testDigits/8_20.txt
# svm_hand_digits/testDigits/8_21.txt
# svm_hand_digits/testDigits/8_22.txt
# svm_hand_digits/testDigits/8_23.txt
# svm_hand_digits/testDigits/8_24.txt
# svm_hand_digits/testDigits/8_25.txt
# svm_hand_digits/testDigits/8_26.txt
# svm_hand_digits/testDigits/8_27.txt
# svm_hand_digits/testDigits/8_28.txt
# svm_hand_digits/testDigits/8_29.txt
# svm_hand_digits/testDigits/8_3.txt
# svm_hand_digits/testDigits/8_30.txt
# svm_hand_digits/testDigits/8_31.txt
# svm_hand_digits/testDigits/8_32.txt
# svm_hand_digits/testDigits/8_33.txt
# svm_hand_digits/testDigits/8_34.txt
# svm_hand_digits/testDigits/8_35.txt
# svm_hand_digits/testDigits/8_36.txt
# svm_hand_digits/testDigits/8_37.txt
# svm_hand_digits/testDigits/8_38.txt
# svm_hand_digits/testDigits/8_39.txt
# svm_hand_digits/testDigits/8_4.txt
# svm_hand_digits/testDigits/8_40.txt
# svm_hand_digits/testDigits/8_41.txt
# svm_hand_digits/testDigits/8_42.txt
# svm_hand_digits/testDigits/8_43.txt
# svm_hand_digits/testDigits/8_44.txt
# svm_hand_digits/testDigits/8_45.txt
# svm_hand_digits/testDigits/8_46.txt
# svm_hand_digits/testDigits/8_47.txt
# svm_hand_digits/testDigits/8_48.txt
# svm_hand_digits/testDigits/8_49.txt
# svm_hand_digits/testDigits/8_5.txt
# svm_hand_digits/testDigits/8_50.txt
# svm_hand_digits/testDigits/8_51.txt
# svm_hand_digits/testDigits/8_52.txt
# svm_hand_digits/testDigits/8_53.txt
# svm_hand_digits/testDigits/8_54.txt
# svm_hand_digits/testDigits/8_55.txt
# svm_hand_digits/testDigits/8_56.txt
# svm_hand_digits/testDigits/8_57.txt
# svm_hand_digits/testDigits/8_58.txt
# svm_hand_digits/testDigits/8_59.txt
# svm_hand_digits/testDigits/8_6.txt
# svm_hand_digits/testDigits/8_60.txt
# svm_hand_digits/testDigits/8_61.txt
# svm_hand_digits/testDigits/8_62.txt
# svm_hand_digits/testDigits/8_63.txt
# svm_hand_digits/testDigits/8_64.txt
# svm_hand_digits/testDigits/8_65.txt
# svm_hand_digits/testDigits/8_66.txt
# svm_hand_digits/testDigits/8_67.txt
# svm_hand_digits/testDigits/8_68.txt
# svm_hand_digits/testDigits/8_69.txt
# svm_hand_digits/testDigits/8_7.txt
# svm_hand_digits/testDigits/8_70.txt
# svm_hand_digits/testDigits/8_71.txt
# svm_hand_digits/testDigits/8_72.txt
# svm_hand_digits/testDigits/8_73.txt
# svm_hand_digits/testDigits/8_74.txt
# svm_hand_digits/testDigits/8_75.txt
# svm_hand_digits/testDigits/8_76.txt
# svm_hand_digits/testDigits/8_77.txt
# svm_hand_digits/testDigits/8_78.txt
# svm_hand_digits/testDigits/8_79.txt
# svm_hand_digits/testDigits/8_8.txt
# svm_hand_digits/testDigits/8_80.txt
# svm_hand_digits/testDigits/8_81.txt
# svm_hand_digits/testDigits/8_82.txt
# svm_hand_digits/testDigits/8_83.txt
# svm_hand_digits/testDigits/8_84.txt
# svm_hand_digits/testDigits/8_85.txt
# svm_hand_digits/testDigits/8_86.txt
# svm_hand_digits/testDigits/8_87.txt
# svm_hand_digits/testDigits/8_88.txt
# svm_hand_digits/testDigits/8_89.txt
# svm_hand_digits/testDigits/8_9.txt
# svm_hand_digits/testDigits/8_90.txt
# svm_hand_digits/testDigits/9_0.txt
# svm_hand_digits/testDigits/9_1.txt
# svm_hand_digits/testDigits/9_10.txt
# svm_hand_digits/testDigits/9_11.txt
# svm_hand_digits/testDigits/9_12.txt
# svm_hand_digits/testDigits/9_13.txt
# svm_hand_digits/testDigits/9_14.txt
# svm_hand_digits/testDigits/9_15.txt
# svm_hand_digits/testDigits/9_16.txt
# svm_hand_digits/testDigits/9_17.txt
# svm_hand_digits/testDigits/9_18.txt
# svm_hand_digits/testDigits/9_19.txt
# svm_hand_digits/testDigits/9_2.txt
# svm_hand_digits/testDigits/9_20.txt
# svm_hand_digits/testDigits/9_21.txt
# svm_hand_digits/testDigits/9_22.txt
# svm_hand_digits/testDigits/9_23.txt
# svm_hand_digits/testDigits/9_24.txt
# svm_hand_digits/testDigits/9_25.txt
# svm_hand_digits/testDigits/9_26.txt
# svm_hand_digits/testDigits/9_27.txt
# svm_hand_digits/testDigits/9_28.txt
# svm_hand_digits/testDigits/9_29.txt
# svm_hand_digits/testDigits/9_3.txt
# svm_hand_digits/testDigits/9_30.txt
# svm_hand_digits/testDigits/9_31.txt
# svm_hand_digits/testDigits/9_32.txt
# svm_hand_digits/testDigits/9_33.txt
# svm_hand_digits/testDigits/9_34.txt
# svm_hand_digits/testDigits/9_35.txt
# svm_hand_digits/testDigits/9_36.txt
# svm_hand_digits/testDigits/9_37.txt
# svm_hand_digits/testDigits/9_38.txt
# svm_hand_digits/testDigits/9_39.txt
# svm_hand_digits/testDigits/9_4.txt
# svm_hand_digits/testDigits/9_40.txt
# svm_hand_digits/testDigits/9_41.txt
# svm_hand_digits/testDigits/9_42.txt
# svm_hand_digits/testDigits/9_43.txt
# svm_hand_digits/testDigits/9_44.txt
# svm_hand_digits/testDigits/9_45.txt
# svm_hand_digits/testDigits/9_46.txt
# svm_hand_digits/testDigits/9_47.txt
# svm_hand_digits/testDigits/9_48.txt
# svm_hand_digits/testDigits/9_49.txt
# svm_hand_digits/testDigits/9_5.txt
# svm_hand_digits/testDigits/9_50.txt
# svm_hand_digits/testDigits/9_51.txt
# svm_hand_digits/testDigits/9_52.txt
# svm_hand_digits/testDigits/9_53.txt
# svm_hand_digits/testDigits/9_54.txt
# svm_hand_digits/testDigits/9_55.txt
# svm_hand_digits/testDigits/9_56.txt
# svm_hand_digits/testDigits/9_57.txt
# svm_hand_digits/testDigits/9_58.txt
# svm_hand_digits/testDigits/9_59.txt
# svm_hand_digits/testDigits/9_6.txt
# svm_hand_digits/testDigits/9_60.txt
# svm_hand_digits/testDigits/9_61.txt
# svm_hand_digits/testDigits/9_62.txt
# svm_hand_digits/testDigits/9_63.txt
# svm_hand_digits/testDigits/9_64.txt
# svm_hand_digits/testDigits/9_65.txt
# svm_hand_digits/testDigits/9_66.txt
# svm_hand_digits/testDigits/9_67.txt
# svm_hand_digits/testDigits/9_68.txt
# svm_hand_digits/testDigits/9_69.txt
# svm_hand_digits/testDigits/9_7.txt
# svm_hand_digits/testDigits/9_70.txt
# svm_hand_digits/testDigits/9_71.txt
# svm_hand_digits/testDigits/9_72.txt
# svm_hand_digits/testDigits/9_73.txt
# svm_hand_digits/testDigits/9_74.txt
# svm_hand_digits/testDigits/9_75.txt
# svm_hand_digits/testDigits/9_76.txt
# svm_hand_digits/testDigits/9_77.txt
# svm_hand_digits/testDigits/9_78.txt
# svm_hand_digits/testDigits/9_79.txt
# svm_hand_digits/testDigits/9_8.txt
# svm_hand_digits/testDigits/9_80.txt
# svm_hand_digits/testDigits/9_81.txt
# svm_hand_digits/testDigits/9_82.txt
# svm_hand_digits/testDigits/9_83.txt
# svm_hand_digits/testDigits/9_84.txt
# svm_hand_digits/testDigits/9_85.txt
# svm_hand_digits/testDigits/9_86.txt
# svm_hand_digits/testDigits/9_87.txt
# svm_hand_digits/testDigits/9_88.txt
# svm_hand_digits/testDigits/9_9.txt
# svm_hand_digits/trainingDigits/
# svm_hand_digits/trainingDigits/0_0.txt
# svm_hand_digits/trainingDigits/0_1.txt
# svm_hand_digits/trainingDigits/0_10.txt
# svm_hand_digits/trainingDigits/0_100.txt
# svm_hand_digits/trainingDigits/0_101.txt
# svm_hand_digits/trainingDigits/0_102.txt
# svm_hand_digits/trainingDigits/0_103.txt
# svm_hand_digits/trainingDigits/0_104.txt
# svm_hand_digits/trainingDigits/0_105.txt
# svm_hand_digits/trainingDigits/0_106.txt
# svm_hand_digits/trainingDigits/0_107.txt
# svm_hand_digits/trainingDigits/0_108.txt
# svm_hand_digits/trainingDigits/0_109.txt
# svm_hand_digits/trainingDigits/0_11.txt
# svm_hand_digits/trainingDigits/0_110.txt
# svm_hand_digits/trainingDigits/0_111.txt
# svm_hand_digits/trainingDigits/0_112.txt
# svm_hand_digits/trainingDigits/0_113.txt
# svm_hand_digits/trainingDigits/0_114.txt
# svm_hand_digits/trainingDigits/0_115.txt
# svm_hand_digits/trainingDigits/0_116.txt
# svm_hand_digits/trainingDigits/0_117.txt
# svm_hand_digits/trainingDigits/0_118.txt
# svm_hand_digits/trainingDigits/0_119.txt
# svm_hand_digits/trainingDigits/0_12.txt
# svm_hand_digits/trainingDigits/0_120.txt
# svm_hand_digits/trainingDigits/0_121.txt
# svm_hand_digits/trainingDigits/0_122.txt
# svm_hand_digits/trainingDigits/0_123.txt
# svm_hand_digits/trainingDigits/0_124.txt
# svm_hand_digits/trainingDigits/0_125.txt
# svm_hand_digits/trainingDigits/0_126.txt
# svm_hand_digits/trainingDigits/0_127.txt
# svm_hand_digits/trainingDigits/0_128.txt
# svm_hand_digits/trainingDigits/0_129.txt
# svm_hand_digits/trainingDigits/0_13.txt
# svm_hand_digits/trainingDigits/0_130.txt
# svm_hand_digits/trainingDigits/0_131.txt
# svm_hand_digits/trainingDigits/0_132.txt
# svm_hand_digits/trainingDigits/0_133.txt
# svm_hand_digits/trainingDigits/0_134.txt
# svm_hand_digits/trainingDigits/0_135.txt
# svm_hand_digits/trainingDigits/0_136.txt
# svm_hand_digits/trainingDigits/0_137.txt
# svm_hand_digits/trainingDigits/0_138.txt
# svm_hand_digits/trainingDigits/0_139.txt
# svm_hand_digits/trainingDigits/0_14.txt
# svm_hand_digits/trainingDigits/0_140.txt
# svm_hand_digits/trainingDigits/0_141.txt
# svm_hand_digits/trainingDigits/0_142.txt
# svm_hand_digits/trainingDigits/0_143.txt
# svm_hand_digits/trainingDigits/0_144.txt
# svm_hand_digits/trainingDigits/0_145.txt
# svm_hand_digits/trainingDigits/0_146.txt
# svm_hand_digits/trainingDigits/0_147.txt
# svm_hand_digits/trainingDigits/0_148.txt
# svm_hand_digits/trainingDigits/0_149.txt
# svm_hand_digits/trainingDigits/0_15.txt
# svm_hand_digits/trainingDigits/0_150.txt
# svm_hand_digits/trainingDigits/0_151.txt
# svm_hand_digits/trainingDigits/0_152.txt
# svm_hand_digits/trainingDigits/0_153.txt
# svm_hand_digits/trainingDigits/0_154.txt
# svm_hand_digits/trainingDigits/0_155.txt
# svm_hand_digits/trainingDigits/0_156.txt
# svm_hand_digits/trainingDigits/0_157.txt
# svm_hand_digits/trainingDigits/0_158.txt
# svm_hand_digits/trainingDigits/0_159.txt
# svm_hand_digits/trainingDigits/0_16.txt
# svm_hand_digits/trainingDigits/0_160.txt
# svm_hand_digits/trainingDigits/0_161.txt
# svm_hand_digits/trainingDigits/0_162.txt
# svm_hand_digits/trainingDigits/0_163.txt
# svm_hand_digits/trainingDigits/0_164.txt
# svm_hand_digits/trainingDigits/0_165.txt
# svm_hand_digits/trainingDigits/0_166.txt
# svm_hand_digits/trainingDigits/0_167.txt
# svm_hand_digits/trainingDigits/0_168.txt
# svm_hand_digits/trainingDigits/0_169.txt
# svm_hand_digits/trainingDigits/0_17.txt
# svm_hand_digits/trainingDigits/0_170.txt
# svm_hand_digits/trainingDigits/0_171.txt
# svm_hand_digits/trainingDigits/0_172.txt
# svm_hand_digits/trainingDigits/0_173.txt
# svm_hand_digits/trainingDigits/0_174.txt
# svm_hand_digits/trainingDigits/0_175.txt
# svm_hand_digits/trainingDigits/0_176.txt
# svm_hand_digits/trainingDigits/0_177.txt
# svm_hand_digits/trainingDigits/0_178.txt
# svm_hand_digits/trainingDigits/0_179.txt
# svm_hand_digits/trainingDigits/0_18.txt
# svm_hand_digits/trainingDigits/0_180.txt
# svm_hand_digits/trainingDigits/0_181.txt
# svm_hand_digits/trainingDigits/0_182.txt
# svm_hand_digits/trainingDigits/0_183.txt
# svm_hand_digits/trainingDigits/0_184.txt
# svm_hand_digits/trainingDigits/0_185.txt
# svm_hand_digits/trainingDigits/0_186.txt
# svm_hand_digits/trainingDigits/0_187.txt
# svm_hand_digits/trainingDigits/0_188.txt
# svm_hand_digits/trainingDigits/0_19.txt
# svm_hand_digits/trainingDigits/0_2.txt
# svm_hand_digits/trainingDigits/0_20.txt
# svm_hand_digits/trainingDigits/0_21.txt
# svm_hand_digits/trainingDigits/0_22.txt
# svm_hand_digits/trainingDigits/0_23.txt
# svm_hand_digits/trainingDigits/0_24.txt
# svm_hand_digits/trainingDigits/0_25.txt
# svm_hand_digits/trainingDigits/0_26.txt
# svm_hand_digits/trainingDigits/0_27.txt
# svm_hand_digits/trainingDigits/0_28.txt
# svm_hand_digits/trainingDigits/0_29.txt
# svm_hand_digits/trainingDigits/0_3.txt
# svm_hand_digits/trainingDigits/0_30.txt
# svm_hand_digits/trainingDigits/0_31.txt
# svm_hand_digits/trainingDigits/0_32.txt
# svm_hand_digits/trainingDigits/0_33.txt
# svm_hand_digits/trainingDigits/0_34.txt
# svm_hand_digits/trainingDigits/0_35.txt
# svm_hand_digits/trainingDigits/0_36.txt
# svm_hand_digits/trainingDigits/0_37.txt
# svm_hand_digits/trainingDigits/0_38.txt
# svm_hand_digits/trainingDigits/0_39.txt
# svm_hand_digits/trainingDigits/0_4.txt
# svm_hand_digits/trainingDigits/0_40.txt
# svm_hand_digits/trainingDigits/0_41.txt
# svm_hand_digits/trainingDigits/0_42.txt
# svm_hand_digits/trainingDigits/0_43.txt
# svm_hand_digits/trainingDigits/0_44.txt
# svm_hand_digits/trainingDigits/0_45.txt
# svm_hand_digits/trainingDigits/0_46.txt
# svm_hand_digits/trainingDigits/0_47.txt
# svm_hand_digits/trainingDigits/0_48.txt
# svm_hand_digits/trainingDigits/0_49.txt
# svm_hand_digits/trainingDigits/0_5.txt
# svm_hand_digits/trainingDigits/0_50.txt
# svm_hand_digits/trainingDigits/0_51.txt
# svm_hand_digits/trainingDigits/0_52.txt
# svm_hand_digits/trainingDigits/0_53.txt
# svm_hand_digits/trainingDigits/0_54.txt
# svm_hand_digits/trainingDigits/0_55.txt
# svm_hand_digits/trainingDigits/0_56.txt
# svm_hand_digits/trainingDigits/0_57.txt
# svm_hand_digits/trainingDigits/0_58.txt
# svm_hand_digits/trainingDigits/0_59.txt
# svm_hand_digits/trainingDigits/0_6.txt
# svm_hand_digits/trainingDigits/0_60.txt
# svm_hand_digits/trainingDigits/0_61.txt
# svm_hand_digits/trainingDigits/0_62.txt
# svm_hand_digits/trainingDigits/0_63.txt
# svm_hand_digits/trainingDigits/0_64.txt
# svm_hand_digits/trainingDigits/0_65.txt
# svm_hand_digits/trainingDigits/0_66.txt
# svm_hand_digits/trainingDigits/0_67.txt
# svm_hand_digits/trainingDigits/0_68.txt
# svm_hand_digits/trainingDigits/0_69.txt
# svm_hand_digits/trainingDigits/0_7.txt
# svm_hand_digits/trainingDigits/0_70.txt
# svm_hand_digits/trainingDigits/0_71.txt
# svm_hand_digits/trainingDigits/0_72.txt
# svm_hand_digits/trainingDigits/0_73.txt
# svm_hand_digits/trainingDigits/0_74.txt
# svm_hand_digits/trainingDigits/0_75.txt
# svm_hand_digits/trainingDigits/0_76.txt
# svm_hand_digits/trainingDigits/0_77.txt
# svm_hand_digits/trainingDigits/0_78.txt
# svm_hand_digits/trainingDigits/0_79.txt
# svm_hand_digits/trainingDigits/0_8.txt
# svm_hand_digits/trainingDigits/0_80.txt
# svm_hand_digits/trainingDigits/0_81.txt
# svm_hand_digits/trainingDigits/0_82.txt
# svm_hand_digits/trainingDigits/0_83.txt
# svm_hand_digits/trainingDigits/0_84.txt
# svm_hand_digits/trainingDigits/0_85.txt
# svm_hand_digits/trainingDigits/0_86.txt
# svm_hand_digits/trainingDigits/0_87.txt
# svm_hand_digits/trainingDigits/0_88.txt
# svm_hand_digits/trainingDigits/0_89.txt
# svm_hand_digits/trainingDigits/0_9.txt
# svm_hand_digits/trainingDigits/0_90.txt
# svm_hand_digits/trainingDigits/0_91.txt
# svm_hand_digits/trainingDigits/0_92.txt
# svm_hand_digits/trainingDigits/0_93.txt
# svm_hand_digits/trainingDigits/0_94.txt
# svm_hand_digits/trainingDigits/0_95.txt
# svm_hand_digits/trainingDigits/0_96.txt
# svm_hand_digits/trainingDigits/0_97.txt
# svm_hand_digits/trainingDigits/0_98.txt
# svm_hand_digits/trainingDigits/0_99.txt
# svm_hand_digits/trainingDigits/1_0.txt
# svm_hand_digits/trainingDigits/1_1.txt
# svm_hand_digits/trainingDigits/1_10.txt
# svm_hand_digits/trainingDigits/1_100.txt
# svm_hand_digits/trainingDigits/1_101.txt
# svm_hand_digits/trainingDigits/1_102.txt
# svm_hand_digits/trainingDigits/1_103.txt
# svm_hand_digits/trainingDigits/1_104.txt
# svm_hand_digits/trainingDigits/1_105.txt
# svm_hand_digits/trainingDigits/1_106.txt
# svm_hand_digits/trainingDigits/1_107.txt
# svm_hand_digits/trainingDigits/1_108.txt
# svm_hand_digits/trainingDigits/1_109.txt
# svm_hand_digits/trainingDigits/1_11.txt
# svm_hand_digits/trainingDigits/1_110.txt
# svm_hand_digits/trainingDigits/1_111.txt
# svm_hand_digits/trainingDigits/1_112.txt
# svm_hand_digits/trainingDigits/1_113.txt
# svm_hand_digits/trainingDigits/1_114.txt
# svm_hand_digits/trainingDigits/1_115.txt
# svm_hand_digits/trainingDigits/1_116.txt
# svm_hand_digits/trainingDigits/1_117.txt
# svm_hand_digits/trainingDigits/1_118.txt
# svm_hand_digits/trainingDigits/1_119.txt
# svm_hand_digits/trainingDigits/1_12.txt
# svm_hand_digits/trainingDigits/1_120.txt
# svm_hand_digits/trainingDigits/1_121.txt
# svm_hand_digits/trainingDigits/1_122.txt
# svm_hand_digits/trainingDigits/1_123.txt
# svm_hand_digits/trainingDigits/1_124.txt
# svm_hand_digits/trainingDigits/1_125.txt
# svm_hand_digits/trainingDigits/1_126.txt
# svm_hand_digits/trainingDigits/1_127.txt
# svm_hand_digits/trainingDigits/1_128.txt
# svm_hand_digits/trainingDigits/1_129.txt
# svm_hand_digits/trainingDigits/1_13.txt
# svm_hand_digits/trainingDigits/1_130.txt
# svm_hand_digits/trainingDigits/1_131.txt
# svm_hand_digits/trainingDigits/1_132.txt
# svm_hand_digits/trainingDigits/1_133.txt
# svm_hand_digits/trainingDigits/1_134.txt
# svm_hand_digits/trainingDigits/1_135.txt
# svm_hand_digits/trainingDigits/1_136.txt
# svm_hand_digits/trainingDigits/1_137.txt
# svm_hand_digits/trainingDigits/1_138.txt
# svm_hand_digits/trainingDigits/1_139.txt
# svm_hand_digits/trainingDigits/1_14.txt
# svm_hand_digits/trainingDigits/1_140.txt
# svm_hand_digits/trainingDigits/1_141.txt
# svm_hand_digits/trainingDigits/1_142.txt
# svm_hand_digits/trainingDigits/1_143.txt
# svm_hand_digits/trainingDigits/1_144.txt
# svm_hand_digits/trainingDigits/1_145.txt
# svm_hand_digits/trainingDigits/1_146.txt
# svm_hand_digits/trainingDigits/1_147.txt
# svm_hand_digits/trainingDigits/1_148.txt
# svm_hand_digits/trainingDigits/1_149.txt
# svm_hand_digits/trainingDigits/1_15.txt
# svm_hand_digits/trainingDigits/1_150.txt
# svm_hand_digits/trainingDigits/1_151.txt
# svm_hand_digits/trainingDigits/1_152.txt
# svm_hand_digits/trainingDigits/1_153.txt
# svm_hand_digits/trainingDigits/1_154.txt
# svm_hand_digits/trainingDigits/1_155.txt
# svm_hand_digits/trainingDigits/1_156.txt
# svm_hand_digits/trainingDigits/1_157.txt
# svm_hand_digits/trainingDigits/1_158.txt
# svm_hand_digits/trainingDigits/1_159.txt
# svm_hand_digits/trainingDigits/1_16.txt
# svm_hand_digits/trainingDigits/1_160.txt
# svm_hand_digits/trainingDigits/1_161.txt
# svm_hand_digits/trainingDigits/1_162.txt
# svm_hand_digits/trainingDigits/1_163.txt
# svm_hand_digits/trainingDigits/1_164.txt
# svm_hand_digits/trainingDigits/1_165.txt
# svm_hand_digits/trainingDigits/1_166.txt
# svm_hand_digits/trainingDigits/1_167.txt
# svm_hand_digits/trainingDigits/1_168.txt
# svm_hand_digits/trainingDigits/1_169.txt
# svm_hand_digits/trainingDigits/1_17.txt
# svm_hand_digits/trainingDigits/1_170.txt
# svm_hand_digits/trainingDigits/1_171.txt
# svm_hand_digits/trainingDigits/1_172.txt
# svm_hand_digits/trainingDigits/1_173.txt
# svm_hand_digits/trainingDigits/1_174.txt
# svm_hand_digits/trainingDigits/1_175.txt
# svm_hand_digits/trainingDigits/1_176.txt
# svm_hand_digits/trainingDigits/1_177.txt
# svm_hand_digits/trainingDigits/1_178.txt
# svm_hand_digits/trainingDigits/1_179.txt
# svm_hand_digits/trainingDigits/1_18.txt
# svm_hand_digits/trainingDigits/1_180.txt
# svm_hand_digits/trainingDigits/1_181.txt
# svm_hand_digits/trainingDigits/1_182.txt
# svm_hand_digits/trainingDigits/1_183.txt
# svm_hand_digits/trainingDigits/1_184.txt
# svm_hand_digits/trainingDigits/1_185.txt
# svm_hand_digits/trainingDigits/1_186.txt
# svm_hand_digits/trainingDigits/1_187.txt
# svm_hand_digits/trainingDigits/1_188.txt
# svm_hand_digits/trainingDigits/1_189.txt
# svm_hand_digits/trainingDigits/1_19.txt
# svm_hand_digits/trainingDigits/1_190.txt
# svm_hand_digits/trainingDigits/1_191.txt
# svm_hand_digits/trainingDigits/1_192.txt
# svm_hand_digits/trainingDigits/1_193.txt
# svm_hand_digits/trainingDigits/1_194.txt
# svm_hand_digits/trainingDigits/1_195.txt
# svm_hand_digits/trainingDigits/1_196.txt
# svm_hand_digits/trainingDigits/1_197.txt
# svm_hand_digits/trainingDigits/1_2.txt
# svm_hand_digits/trainingDigits/1_20.txt
# svm_hand_digits/trainingDigits/1_21.txt
# svm_hand_digits/trainingDigits/1_22.txt
# svm_hand_digits/trainingDigits/1_23.txt
# svm_hand_digits/trainingDigits/1_24.txt
# svm_hand_digits/trainingDigits/1_25.txt
# svm_hand_digits/trainingDigits/1_26.txt
# svm_hand_digits/trainingDigits/1_27.txt
# svm_hand_digits/trainingDigits/1_28.txt
# svm_hand_digits/trainingDigits/1_29.txt
# svm_hand_digits/trainingDigits/1_3.txt
# svm_hand_digits/trainingDigits/1_30.txt
# svm_hand_digits/trainingDigits/1_31.txt
# svm_hand_digits/trainingDigits/1_32.txt
# svm_hand_digits/trainingDigits/1_33.txt
# svm_hand_digits/trainingDigits/1_34.txt
# svm_hand_digits/trainingDigits/1_35.txt
# svm_hand_digits/trainingDigits/1_36.txt
# svm_hand_digits/trainingDigits/1_37.txt
# svm_hand_digits/trainingDigits/1_38.txt
# svm_hand_digits/trainingDigits/1_39.txt
# svm_hand_digits/trainingDigits/1_4.txt
# svm_hand_digits/trainingDigits/1_40.txt
# svm_hand_digits/trainingDigits/1_41.txt
# svm_hand_digits/trainingDigits/1_42.txt
# svm_hand_digits/trainingDigits/1_43.txt
# svm_hand_digits/trainingDigits/1_44.txt
# svm_hand_digits/trainingDigits/1_45.txt
# svm_hand_digits/trainingDigits/1_46.txt
# svm_hand_digits/trainingDigits/1_47.txt
# svm_hand_digits/trainingDigits/1_48.txt
# svm_hand_digits/trainingDigits/1_49.txt
# svm_hand_digits/trainingDigits/1_5.txt
# svm_hand_digits/trainingDigits/1_50.txt
# svm_hand_digits/trainingDigits/1_51.txt
# svm_hand_digits/trainingDigits/1_52.txt
# svm_hand_digits/trainingDigits/1_53.txt
# svm_hand_digits/trainingDigits/1_54.txt
# svm_hand_digits/trainingDigits/1_55.txt
# svm_hand_digits/trainingDigits/1_56.txt
# svm_hand_digits/trainingDigits/1_57.txt
# svm_hand_digits/trainingDigits/1_58.txt
# svm_hand_digits/trainingDigits/1_59.txt
# svm_hand_digits/trainingDigits/1_6.txt
# ...
# svm_hand_digits/trainingDigits/7_9.txt
# svm_hand_digits/trainingDigits/7_90.txt
# svm_hand_digits/trainingDigits/7_91.txt
# svm_hand_digits/trainingDigits/7_92.txt
# svm_hand_digits/trainingDigits/7_93.txt
# svm_hand_digits/trainingDigits/7_94.txt
# svm_hand_digits/trainingDigits/7_95.txt
# svm_hand_digits/trainingDigits/7_96.txt
# svm_hand_digits/trainingDigits/7_97.txt
# svm_hand_digits/trainingDigits/7_98.txt
# svm_hand_digits/trainingDigits/7_99.txt
# svm_hand_digits/trainingDigits/8_0.txt
# svm_hand_digits/trainingDigits/8_1.txt
# svm_hand_digits/trainingDigits/8_10.txt
# svm_hand_digits/trainingDigits/8_100.txt
# svm_hand_digits/trainingDigits/8_101.txt
# svm_hand_digits/trainingDigits/8_102.txt
# svm_hand_digits/trainingDigits/8_103.txt
# svm_hand_digits/trainingDigits/8_104.txt
# svm_hand_digits/trainingDigits/8_105.txt
# svm_hand_digits/trainingDigits/8_106.txt
# svm_hand_digits/trainingDigits/8_107.txt
# svm_hand_digits/trainingDigits/8_108.txt
# svm_hand_digits/trainingDigits/8_109.txt
# svm_hand_digits/trainingDigits/8_11.txt
# svm_hand_digits/trainingDigits/8_110.txt
# svm_hand_digits/trainingDigits/8_111.txt
# svm_hand_digits/trainingDigits/8_112.txt
# svm_hand_digits/trainingDigits/8_113.txt
# svm_hand_digits/trainingDigits/8_114.txt
# svm_hand_digits/trainingDigits/8_115.txt
# svm_hand_digits/trainingDigits/8_116.txt
# svm_hand_digits/trainingDigits/8_117.txt
# svm_hand_digits/trainingDigits/8_118.txt
# svm_hand_digits/trainingDigits/8_119.txt
# svm_hand_digits/trainingDigits/8_12.txt
# svm_hand_digits/trainingDigits/8_120.txt
# svm_hand_digits/trainingDigits/8_121.txt
# svm_hand_digits/trainingDigits/8_122.txt
# svm_hand_digits/trainingDigits/8_123.txt
# svm_hand_digits/trainingDigits/8_124.txt
# svm_hand_digits/trainingDigits/8_125.txt
# svm_hand_digits/trainingDigits/8_126.txt
# svm_hand_digits/trainingDigits/8_127.txt
# svm_hand_digits/trainingDigits/8_128.txt
# svm_hand_digits/trainingDigits/8_129.txt
# svm_hand_digits/trainingDigits/8_13.txt
# svm_hand_digits/trainingDigits/8_130.txt
# svm_hand_digits/trainingDigits/8_131.txt
# svm_hand_digits/trainingDigits/8_132.txt
# svm_hand_digits/trainingDigits/8_133.txt
# svm_hand_digits/trainingDigits/8_134.txt
# svm_hand_digits/trainingDigits/8_135.txt
# svm_hand_digits/trainingDigits/8_136.txt
# svm_hand_digits/trainingDigits/8_137.txt
# svm_hand_digits/trainingDigits/8_138.txt
# svm_hand_digits/trainingDigits/8_139.txt
# svm_hand_digits/trainingDigits/8_14.txt
# svm_hand_digits/trainingDigits/8_140.txt
# svm_hand_digits/trainingDigits/8_141.txt
# svm_hand_digits/trainingDigits/8_142.txt
# svm_hand_digits/trainingDigits/8_143.txt
# svm_hand_digits/trainingDigits/8_144.txt
# svm_hand_digits/trainingDigits/8_145.txt
# svm_hand_digits/trainingDigits/8_146.txt
# svm_hand_digits/trainingDigits/8_147.txt
# svm_hand_digits/trainingDigits/8_148.txt
# svm_hand_digits/trainingDigits/8_149.txt
# svm_hand_digits/trainingDigits/8_15.txt
# svm_hand_digits/trainingDigits/8_150.txt
# svm_hand_digits/trainingDigits/8_151.txt
# svm_hand_digits/trainingDigits/8_152.txt
# svm_hand_digits/trainingDigits/8_153.txt
# svm_hand_digits/trainingDigits/8_154.txt
# svm_hand_digits/trainingDigits/8_155.txt
# svm_hand_digits/trainingDigits/8_156.txt
# svm_hand_digits/trainingDigits/8_157.txt
# svm_hand_digits/trainingDigits/8_158.txt
# svm_hand_digits/trainingDigits/8_159.txt
# svm_hand_digits/trainingDigits/8_16.txt
# svm_hand_digits/trainingDigits/8_160.txt
# svm_hand_digits/trainingDigits/8_161.txt
# svm_hand_digits/trainingDigits/8_162.txt
# svm_hand_digits/trainingDigits/8_163.txt
# svm_hand_digits/trainingDigits/8_164.txt
# svm_hand_digits/trainingDigits/8_165.txt
# svm_hand_digits/trainingDigits/8_166.txt
# svm_hand_digits/trainingDigits/8_167.txt
# svm_hand_digits/trainingDigits/8_168.txt
# svm_hand_digits/trainingDigits/8_169.txt
# svm_hand_digits/trainingDigits/8_17.txt
# svm_hand_digits/trainingDigits/8_170.txt
# svm_hand_digits/trainingDigits/8_171.txt
# svm_hand_digits/trainingDigits/8_172.txt
# svm_hand_digits/trainingDigits/8_173.txt
# svm_hand_digits/trainingDigits/8_174.txt
# svm_hand_digits/trainingDigits/8_175.txt
# svm_hand_digits/trainingDigits/8_176.txt
# svm_hand_digits/trainingDigits/8_177.txt
# svm_hand_digits/trainingDigits/8_178.txt
# svm_hand_digits/trainingDigits/8_179.txt
# svm_hand_digits/trainingDigits/8_18.txt
# svm_hand_digits/trainingDigits/8_19.txt
# svm_hand_digits/trainingDigits/8_2.txt
# svm_hand_digits/trainingDigits/8_20.txt
# svm_hand_digits/trainingDigits/8_21.txt
# svm_hand_digits/trainingDigits/8_22.txt
# svm_hand_digits/trainingDigits/8_23.txt
# svm_hand_digits/trainingDigits/8_24.txt
# svm_hand_digits/trainingDigits/8_25.txt
# svm_hand_digits/trainingDigits/8_26.txt
# svm_hand_digits/trainingDigits/8_27.txt
# svm_hand_digits/trainingDigits/8_28.txt
# svm_hand_digits/trainingDigits/8_29.txt
# svm_hand_digits/trainingDigits/8_3.txt
# svm_hand_digits/trainingDigits/8_30.txt
# svm_hand_digits/trainingDigits/8_31.txt
# svm_hand_digits/trainingDigits/8_32.txt
# svm_hand_digits/trainingDigits/8_33.txt
# svm_hand_digits/trainingDigits/8_34.txt
# svm_hand_digits/trainingDigits/8_35.txt
# svm_hand_digits/trainingDigits/8_36.txt
# svm_hand_digits/trainingDigits/8_37.txt
# svm_hand_digits/trainingDigits/8_38.txt
# svm_hand_digits/trainingDigits/8_39.txt
# svm_hand_digits/trainingDigits/8_4.txt
# svm_hand_digits/trainingDigits/8_40.txt
# svm_hand_digits/trainingDigits/8_41.txt
# svm_hand_digits/trainingDigits/8_42.txt
# svm_hand_digits/trainingDigits/8_43.txt
# svm_hand_digits/trainingDigits/8_44.txt
# svm_hand_digits/trainingDigits/8_45.txt
# svm_hand_digits/trainingDigits/8_46.txt
# svm_hand_digits/trainingDigits/8_47.txt
# svm_hand_digits/trainingDigits/8_48.txt
# svm_hand_digits/trainingDigits/8_49.txt
# svm_hand_digits/trainingDigits/8_5.txt
# svm_hand_digits/trainingDigits/8_50.txt
# svm_hand_digits/trainingDigits/8_51.txt
# svm_hand_digits/trainingDigits/8_52.txt
# svm_hand_digits/trainingDigits/8_53.txt
# svm_hand_digits/trainingDigits/8_54.txt
# svm_hand_digits/trainingDigits/8_55.txt
# svm_hand_digits/trainingDigits/8_56.txt
# svm_hand_digits/trainingDigits/8_57.txt
# svm_hand_digits/trainingDigits/8_58.txt
# svm_hand_digits/trainingDigits/8_59.txt
# svm_hand_digits/trainingDigits/8_6.txt
# svm_hand_digits/trainingDigits/8_60.txt
# svm_hand_digits/trainingDigits/8_61.txt
# svm_hand_digits/trainingDigits/8_62.txt
# svm_hand_digits/trainingDigits/8_63.txt
# svm_hand_digits/trainingDigits/8_64.txt
# svm_hand_digits/trainingDigits/8_65.txt
# svm_hand_digits/trainingDigits/8_66.txt
# svm_hand_digits/trainingDigits/8_67.txt
# svm_hand_digits/trainingDigits/8_68.txt
# svm_hand_digits/trainingDigits/8_69.txt
# svm_hand_digits/trainingDigits/8_7.txt
# svm_hand_digits/trainingDigits/8_70.txt
# svm_hand_digits/trainingDigits/8_71.txt
# svm_hand_digits/trainingDigits/8_72.txt
# svm_hand_digits/trainingDigits/8_73.txt
# svm_hand_digits/trainingDigits/8_74.txt
# svm_hand_digits/trainingDigits/8_75.txt
# svm_hand_digits/trainingDigits/8_76.txt
# svm_hand_digits/trainingDigits/8_77.txt
# svm_hand_digits/trainingDigits/8_78.txt
# svm_hand_digits/trainingDigits/8_79.txt
# svm_hand_digits/trainingDigits/8_8.txt
# svm_hand_digits/trainingDigits/8_80.txt
# svm_hand_digits/trainingDigits/8_81.txt
# svm_hand_digits/trainingDigits/8_82.txt
# svm_hand_digits/trainingDigits/8_83.txt
# svm_hand_digits/trainingDigits/8_84.txt
# svm_hand_digits/trainingDigits/8_85.txt
# svm_hand_digits/trainingDigits/8_86.txt
# svm_hand_digits/trainingDigits/8_87.txt
# svm_hand_digits/trainingDigits/8_88.txt
# svm_hand_digits/trainingDigits/8_89.txt
# svm_hand_digits/trainingDigits/8_9.txt
# svm_hand_digits/trainingDigits/8_90.txt
# svm_hand_digits/trainingDigits/8_91.txt
# svm_hand_digits/trainingDigits/8_92.txt
# svm_hand_digits/trainingDigits/8_93.txt
# svm_hand_digits/trainingDigits/8_94.txt
# svm_hand_digits/trainingDigits/8_95.txt
# svm_hand_digits/trainingDigits/8_96.txt
# svm_hand_digits/trainingDigits/8_97.txt
# svm_hand_digits/trainingDigits/8_98.txt
# svm_hand_digits/trainingDigits/8_99.txt
# svm_hand_digits/trainingDigits/9_0.txt
# svm_hand_digits/trainingDigits/9_1.txt
# svm_hand_digits/trainingDigits/9_10.txt
# svm_hand_digits/trainingDigits/9_100.txt
# svm_hand_digits/trainingDigits/9_101.txt
# svm_hand_digits/trainingDigits/9_102.txt
# svm_hand_digits/trainingDigits/9_103.txt
# svm_hand_digits/trainingDigits/9_104.txt
# svm_hand_digits/trainingDigits/9_105.txt
# svm_hand_digits/trainingDigits/9_106.txt
# svm_hand_digits/trainingDigits/9_107.txt
# svm_hand_digits/trainingDigits/9_108.txt
# svm_hand_digits/trainingDigits/9_109.txt
# svm_hand_digits/trainingDigits/9_11.txt
# svm_hand_digits/trainingDigits/9_110.txt
# svm_hand_digits/trainingDigits/9_111.txt
# svm_hand_digits/trainingDigits/9_112.txt
# svm_hand_digits/trainingDigits/9_113.txt
# svm_hand_digits/trainingDigits/9_114.txt
# svm_hand_digits/trainingDigits/9_115.txt
# svm_hand_digits/trainingDigits/9_116.txt
# svm_hand_digits/trainingDigits/9_117.txt
# svm_hand_digits/trainingDigits/9_118.txt
# svm_hand_digits/trainingDigits/9_119.txt
# svm_hand_digits/trainingDigits/9_12.txt
# svm_hand_digits/trainingDigits/9_120.txt
# svm_hand_digits/trainingDigits/9_121.txt
# svm_hand_digits/trainingDigits/9_122.txt
# svm_hand_digits/trainingDigits/9_123.txt
# svm_hand_digits/trainingDigits/9_124.txt
# svm_hand_digits/trainingDigits/9_125.txt
# svm_hand_digits/trainingDigits/9_126.txt
# svm_hand_digits/trainingDigits/9_127.txt
# svm_hand_digits/trainingDigits/9_128.txt
# svm_hand_digits/trainingDigits/9_129.txt
# svm_hand_digits/trainingDigits/9_13.txt
# svm_hand_digits/trainingDigits/9_130.txt
# svm_hand_digits/trainingDigits/9_131.txt
# svm_hand_digits/trainingDigits/9_132.txt
# svm_hand_digits/trainingDigits/9_133.txt
# svm_hand_digits/trainingDigits/9_134.txt
# svm_hand_digits/trainingDigits/9_135.txt
# svm_hand_digits/trainingDigits/9_136.txt
# svm_hand_digits/trainingDigits/9_137.txt
# svm_hand_digits/trainingDigits/9_138.txt
# svm_hand_digits/trainingDigits/9_139.txt
# svm_hand_digits/trainingDigits/9_14.txt
# svm_hand_digits/trainingDigits/9_140.txt
# svm_hand_digits/trainingDigits/9_141.txt
# svm_hand_digits/trainingDigits/9_142.txt
# svm_hand_digits/trainingDigits/9_143.txt
# svm_hand_digits/trainingDigits/9_144.txt
# svm_hand_digits/trainingDigits/9_145.txt
# svm_hand_digits/trainingDigits/9_146.txt
# svm_hand_digits/trainingDigits/9_147.txt
# svm_hand_digits/trainingDigits/9_148.txt
# svm_hand_digits/trainingDigits/9_149.txt
# svm_hand_digits/trainingDigits/9_15.txt
# svm_hand_digits/trainingDigits/9_150.txt
# svm_hand_digits/trainingDigits/9_151.txt
# svm_hand_digits/trainingDigits/9_152.txt
# svm_hand_digits/trainingDigits/9_153.txt
# svm_hand_digits/trainingDigits/9_154.txt
# svm_hand_digits/trainingDigits/9_155.txt
# svm_hand_digits/trainingDigits/9_156.txt
# svm_hand_digits/trainingDigits/9_157.txt
# svm_hand_digits/trainingDigits/9_158.txt
# svm_hand_digits/trainingDigits/9_159.txt
# svm_hand_digits/trainingDigits/9_16.txt
# svm_hand_digits/trainingDigits/9_160.txt
# svm_hand_digits/trainingDigits/9_161.txt
# svm_hand_digits/trainingDigits/9_162.txt
# svm_hand_digits/trainingDigits/9_163.txt
# svm_hand_digits/trainingDigits/9_164.txt
# svm_hand_digits/trainingDigits/9_165.txt
# svm_hand_digits/trainingDigits/9_166.txt
# svm_hand_digits/trainingDigits/9_167.txt
# svm_hand_digits/trainingDigits/9_168.txt
# svm_hand_digits/trainingDigits/9_169.txt
# svm_hand_digits/trainingDigits/9_17.txt
# svm_hand_digits/trainingDigits/9_170.txt
# svm_hand_digits/trainingDigits/9_171.txt
# svm_hand_digits/trainingDigits/9_172.txt
# svm_hand_digits/trainingDigits/9_173.txt
# svm_hand_digits/trainingDigits/9_174.txt
# svm_hand_digits/trainingDigits/9_175.txt
# svm_hand_digits/trainingDigits/9_176.txt
# svm_hand_digits/trainingDigits/9_177.txt
# svm_hand_digits/trainingDigits/9_178.txt
# svm_hand_digits/trainingDigits/9_179.txt
# svm_hand_digits/trainingDigits/9_18.txt
# svm_hand_digits/trainingDigits/9_180.txt
# svm_hand_digits/trainingDigits/9_181.txt
# svm_hand_digits/trainingDigits/9_182.txt
# svm_hand_digits/trainingDigits/9_183.txt
# svm_hand_digits/trainingDigits/9_184.txt
# svm_hand_digits/trainingDigits/9_185.txt
# svm_hand_digits/trainingDigits/9_186.txt
# svm_hand_digits/trainingDigits/9_187.txt
# svm_hand_digits/trainingDigits/9_188.txt
# svm_hand_digits/trainingDigits/9_189.txt
# svm_hand_digits/trainingDigits/9_19.txt
# svm_hand_digits/trainingDigits/9_190.txt
# svm_hand_digits/trainingDigits/9_191.txt
# svm_hand_digits/trainingDigits/9_192.txt
# svm_hand_digits/trainingDigits/9_193.txt
# svm_hand_digits/trainingDigits/9_194.txt
# svm_hand_digits/trainingDigits/9_195.txt
# svm_hand_digits/trainingDigits/9_196.txt
# svm_hand_digits/trainingDigits/9_197.txt
# svm_hand_digits/trainingDigits/9_198.txt
# svm_hand_digits/trainingDigits/9_199.txt
# svm_hand_digits/trainingDigits/9_2.txt
# svm_hand_digits/trainingDigits/9_20.txt
# svm_hand_digits/trainingDigits/9_200.txt
# svm_hand_digits/trainingDigits/9_201.txt
# svm_hand_digits/trainingDigits/9_202.txt
# svm_hand_digits/trainingDigits/9_203.txt
# svm_hand_digits/trainingDigits/9_21.txt
# svm_hand_digits/trainingDigits/9_22.txt
# svm_hand_digits/trainingDigits/9_23.txt
# svm_hand_digits/trainingDigits/9_24.txt
# svm_hand_digits/trainingDigits/9_25.txt
# svm_hand_digits/trainingDigits/9_26.txt
# svm_hand_digits/trainingDigits/9_27.txt
# svm_hand_digits/trainingDigits/9_28.txt
# svm_hand_digits/trainingDigits/9_29.txt
# svm_hand_digits/trainingDigits/9_3.txt
# svm_hand_digits/trainingDigits/9_30.txt
# svm_hand_digits/trainingDigits/9_31.txt
# svm_hand_digits/trainingDigits/9_32.txt
# svm_hand_digits/trainingDigits/9_33.txt
# svm_hand_digits/trainingDigits/9_34.txt
# svm_hand_digits/trainingDigits/9_35.txt
# svm_hand_digits/trainingDigits/9_36.txt
# svm_hand_digits/trainingDigits/9_37.txt
# svm_hand_digits/trainingDigits/9_38.txt
# svm_hand_digits/trainingDigits/9_39.txt
# svm_hand_digits/trainingDigits/9_4.txt
# svm_hand_digits/trainingDigits/9_40.txt
# svm_hand_digits/trainingDigits/9_41.txt
# svm_hand_digits/trainingDigits/9_42.txt
# svm_hand_digits/trainingDigits/9_43.txt
# svm_hand_digits/trainingDigits/9_44.txt
# svm_hand_digits/trainingDigits/9_45.txt
# svm_hand_digits/trainingDigits/9_46.txt
# svm_hand_digits/trainingDigits/9_47.txt
# svm_hand_digits/trainingDigits/9_48.txt
# svm_hand_digits/trainingDigits/9_49.txt
# svm_hand_digits/trainingDigits/9_5.txt
# svm_hand_digits/trainingDigits/9_50.txt
# svm_hand_digits/trainingDigits/9_51.txt
# svm_hand_digits/trainingDigits/9_52.txt
# svm_hand_digits/trainingDigits/9_53.txt
# svm_hand_digits/trainingDigits/9_54.txt
# svm_hand_digits/trainingDigits/9_55.txt
# svm_hand_digits/trainingDigits/9_56.txt
# svm_hand_digits/trainingDigits/9_57.txt
# svm_hand_digits/trainingDigits/9_58.txt
# svm_hand_digits/trainingDigits/9_59.txt
# svm_hand_digits/trainingDigits/9_6.txt
# svm_hand_digits/trainingDigits/9_60.txt
# svm_hand_digits/trainingDigits/9_61.txt
# svm_hand_digits/trainingDigits/9_62.txt
# svm_hand_digits/trainingDigits/9_63.txt
# svm_hand_digits/trainingDigits/9_64.txt
# svm_hand_digits/trainingDigits/9_65.txt
# svm_hand_digits/trainingDigits/9_66.txt
# svm_hand_digits/trainingDigits/9_67.txt
# svm_hand_digits/trainingDigits/9_68.txt
# svm_hand_digits/trainingDigits/9_69.txt
# svm_hand_digits/trainingDigits/9_7.txt
# svm_hand_digits/trainingDigits/9_70.txt
# svm_hand_digits/trainingDigits/9_71.txt
# svm_hand_digits/trainingDigits/9_72.txt
# svm_hand_digits/trainingDigits/9_73.txt
# svm_hand_digits/trainingDigits/9_74.txt
# svm_hand_digits/trainingDigits/9_75.txt
# svm_hand_digits/trainingDigits/9_76.txt
# svm_hand_digits/trainingDigits/9_77.txt
# svm_hand_digits/trainingDigits/9_78.txt
# svm_hand_digits/trainingDigits/9_79.txt
# svm_hand_digits/trainingDigits/9_8.txt
# svm_hand_digits/trainingDigits/9_80.txt
# svm_hand_digits/trainingDigits/9_81.txt
# svm_hand_digits/trainingDigits/9_82.txt
# svm_hand_digits/trainingDigits/9_83.txt
# svm_hand_digits/trainingDigits/9_84.txt
# svm_hand_digits/trainingDigits/9_85.txt
# svm_hand_digits/trainingDigits/9_86.txt
# svm_hand_digits/trainingDigits/9_87.txt
# svm_hand_digits/trainingDigits/9_88.txt
# svm_hand_digits/trainingDigits/9_89.txt
# svm_hand_digits/trainingDigits/9_9.txt
# svm_hand_digits/trainingDigits/9_90.txt
# svm_hand_digits/trainingDigits/9_91.txt
# svm_hand_digits/trainingDigits/9_92.txt
# svm_hand_digits/trainingDigits/9_93.txt
# svm_hand_digits/trainingDigits/9_94.txt
# svm_hand_digits/trainingDigits/9_95.txt
# svm_hand_digits/trainingDigits/9_96.txt
# svm_hand_digits/trainingDigits/9_97.txt
# svm_hand_digits/trainingDigits/9_98.txt
# svm_hand_digits/trainingDigits/9_99.txt

# %% [markdown]
# 本实验的数据集和kNN手写数字识别的数据集相同，在kNN手写数字识别实验中对数据集有详细的介绍，不了解的同学，可以去参考该实验中对数据集的介绍。

# %% [markdown]
# ## 基于SVM的手写数字识别

# %% [markdown]
# 现在我们开始进行基于SVM的手写数字识别实战。

# %% [markdown]
# ## 【实验步骤】读取并处理图片数据

# %% [markdown]
# 本次实验分为以下几个步骤：
# (1)收集数据：提供的文本文件
# (2)准备数据：基于二值图像构造向量
# (3)分析数据：对图像向量进行目测
# (4)训练算法：采用两种不同的核函数，并对径向基函数采用不同的设置来运行SMO算法
# (5)测试算法：编写test函数来测试不同的核函数并计算错误率

# %%
def img2vector(filename):
    """
    将32x32的二进制图像转换为1x1024向量。

    Args:
        filename: 文件名
    Returns:
        returnVect: 返回的二进制图像的1x1024向量
    """
    returnVect = np.zeros((1, 1024))
    fr = open(filename)
    for i in range(32):
        lineStr = fr.readline()
        for j in range(32):
            returnVect[0, 32 * i + j] = int(lineStr[j])
    return returnVect


def loadImages(dirName):
    """
    加载图片

    Args:
        dirName: 文件夹的名字
    Returns:
        trainingMat: 数据矩阵
        hwLabels: 数据标签
    """
    from os import listdir
    hwLabels = []
    trainingFileList = listdir(dirName)
    m = len(trainingFileList)
    trainingMat = np.zeros((m, 1024))
    for i in range(m):
        fileNameStr = trainingFileList[i]
        fileStr = fileNameStr.split('.')[0]
        classNumStr = int(fileStr.split('_')[0])
        if classNumStr == 9:
            hwLabels.append(-1)
        else:
            hwLabels.append(1)
        trainingMat[i, :] = img2vector('%s/%s' % (dirName, fileNameStr))
    return trainingMat, hwLabels

# %% [markdown]
# ## 【练习】构建完整SMO算法

# %% [markdown]
# 本节我们来构建完整的SMO算法：

# %%
import random


class optStruct:
    """
    数据结构，维护所有需要操作的值

    Args:
        dataMatIn: 数据矩阵
        classLabels: 数据标签
        C: 松弛变量
        toler: 容错率
        kTup: 包含核函数信息的元组,第一个参数存放核函数类别，第二个参数存放必要的核函数需要用到的参数
    """

    def __init__(self, dataMatIn, classLabels, C, toler, kTup):
        self.X = dataMatIn  #数据矩阵
        self.labelMat = classLabels  #数据标签
        self.C = C  #松弛变量
        self.tol = toler  #容错率
        self.m = np.shape(dataMatIn)[0]  #数据矩阵行数
        self.alphas = np.mat(np.zeros((self.m, 1)))  #根据矩阵行数初始化alpha参数为0
        self.b = 0  #初始化b参数为0
        self.eCache = np.mat(np.zeros((self.m, 2)))  #根据矩阵行数初始化虎误差缓存，第一列为是否有效的标志位，第二列为实际的误差E的值。
        self.K = np.mat(np.zeros((self.m, self.m)))  #初始化核K
        for i in range(self.m):  #计算所有数据的核K
            self.K[:, i] = kernelTrans(self.X, self.X[i, :], kTup)


def kernelTrans(X, A, kTup):
    """
    通过核函数将数据转换更高维的空间

    Args:
        X: 数据矩阵
        A: 单个数据的向量
        kTup: 包含核函数信息的元组
    Returns:
        K: 计算的核K
    """
    m, n = np.shape(X)
    K = np.mat(np.zeros((m, 1)))
    if kTup[0] == 'lin':
        K = X * A.T  #线性核函数,只进行内积。
    elif kTup[0] == 'rbf':  #高斯核函数,根据高斯核函数公式进行计算
        for j in range(m):
            deltaRow = X[j, :] - A
            K[j] = deltaRow * deltaRow.T
        K = np.exp(K / (-1 * kTup[1] ** 2))  #计算高斯核K
    else:
        raise NameError('核函数无法识别')
    return K


def loadDataSet(fileName):
    """
    读取数据

    Args:
        fileName: 文件名
    Returns:
        dataMat: 数据矩阵
        labelMat: 数据标签
    """
    dataMat = []
    labelMat = []
    fr = open(fileName)
    for line in fr.readlines():  #逐行读取，滤除空格等
        lineArr = line.strip().split('\t')
        dataMat.append([float(lineArr[0]), float(lineArr[1])])  #添加数据
        labelMat.append(float(lineArr[2]))  #添加标签
    return dataMat, labelMat


def calcEk(oS, k):
    """
    计算误差

    Args:
        oS: 数据结构
        k: 标号为k的数据
    Returns:
        Ek: 标号为k的数据误差
    """
    fXk = float(np.multiply(oS.alphas, oS.labelMat).T * oS.K[:, k] + oS.b)
    Ek = fXk - float(oS.labelMat[k])
    return Ek


def selectJrand(i, m):
    """
    函数说明:随机选择alpha_j的索引值

    Args:
        i: alpha_i的索引值
        m: alpha参数个数
    Returns:
        j: alpha_j的索引值
    """
    j = i  #选择一个不等于i的j
    while j == i:
        j = int(random.uniform(0, m))
    return j


def selectJ(i, oS, Ei):
    """
    内循环启发方式2

    Args:
        i: 标号为i的数据的索引值
        oS: 数据结构
        Ei: 标号为i的数据误差
    Returns:
        j, maxK: 标号为j或maxK的数据的索引值
        Ej: 标号为j的数据误差
    """
    maxK = -1
    maxDeltaE = 0
    Ej = 0  #初始化
    oS.eCache[i] = [1, Ei]  #根据Ei更新误差缓存
    validEcacheList = np.nonzero(oS.eCache[:, 0].A)[0]  #返回误差不为0的数据的索引值
    if (len(validEcacheList)) > 1:  #有不为0的误差
        for k in validEcacheList:  #遍历,找到最大的Ek
            if k == i: continue  #不计算i,浪费时间
            Ek = calcEk(oS, k)  #计算Ek
            deltaE = abs(Ei - Ek)  #计算|Ei-Ek|
            if (deltaE > maxDeltaE):  #找到maxDeltaE
                maxK = k;
                maxDeltaE = deltaE;
                Ej = Ek
        return maxK, Ej  #返回maxK,Ej
    else:  #没有不为0的误差
        j = selectJrand(i, oS.m)  #随机选择alpha_j的索引值
        Ej = calcEk(oS, j)  #计算Ej
    return j, Ej


def updateEk(oS, k):
    """
    计算Ek,并更新误差缓存

    Args:
        oS: 数据结构
        k: 标号为k的数据的索引值
    Returns:
        无
    """
    Ek = calcEk(oS, k)  #计算Ek
    oS.eCache[k] = [1, Ek]  #更新误差缓存


def clipAlpha(aj, H, L):
    """
    修剪alpha_j

    Args:
        aj: alpha_j的值
        H: alpha上限
        L: alpha下限
    Returns:
        aj: 修剪后的alpah_j的值
    """
    if aj > H:
        aj = H
    if L > aj:
        aj = L
    return aj


def innerL(i, oS):
    """
    优化的SMO算法

    Args:
        i: 标号为i的数据的索引值
        oS: 数据结构
    Returns:
        1: 有任意一对alpha值发生变化
        0: 没有任意一对alpha值发生变化或变化太小
    """
    #步骤1：计算误差Ei
    Ei = calcEk(oS, i)
    #优化alpha,设定一定的容错率。
    if ((oS.labelMat[i] * Ei < -oS.tol) and (oS.alphas[i] < oS.C)) or (
            (oS.labelMat[i] * Ei > oS.tol) and (oS.alphas[i] > 0)):
        #使用内循环启发方式2选择alpha_j,并计算Ej
        j, Ej = selectJ(i, oS, Ei)
        #保存更新前的aplpha值，使用深拷贝
        alphaIold = oS.alphas[i].copy();
        alphaJold = oS.alphas[j].copy();
        #步骤2：计算上下界L和H
        if (oS.labelMat[i] != oS.labelMat[j]):
            L = max(0, oS.alphas[j] - oS.alphas[i])
            H = min(oS.C, oS.C + oS.alphas[j] - oS.alphas[i])
        else:
            L = max(0, oS.alphas[j] + oS.alphas[i] - oS.C)
            H = min(oS.C, oS.alphas[j] + oS.alphas[i])
        if L == H:
            print("L==H")
            return 0
        #步骤3：计算eta
        eta = 2.0 * oS.K[i, j] - oS.K[i, i] - oS.K[j, j]
        if eta >= 0:
            print("eta>=0")
            return 0
        #步骤4：更新alpha_j
        oS.alphas[j] -= oS.labelMat[j] * (Ei - Ej) / eta
        #步骤5：修剪alpha_j
        oS.alphas[j] = clipAlpha(oS.alphas[j], H, L)
        #更新Ej至误差缓存
        updateEk(oS, j)
        if (abs(oS.alphas[j] - alphaJold) < 0.00001):
            print("alpha_j变化太小")
            return 0
        #步骤6：更新alpha_i
        oS.alphas[i] += oS.labelMat[j] * oS.labelMat[i] * (alphaJold - oS.alphas[j])
        #更新Ei至误差缓存
        updateEk(oS, i)
        #步骤7：更新b_1和b_2
        b1 = oS.b - Ei - oS.labelMat[i] * (oS.alphas[i] - alphaIold) * oS.K[i, i] - oS.labelMat[j] * (
                oS.alphas[j] - alphaJold) * oS.K[i, j]
        b2 = oS.b - Ej - oS.labelMat[i] * (oS.alphas[i] - alphaIold) * oS.K[i, j] - oS.labelMat[j] * (
                oS.alphas[j] - alphaJold) * oS.K[j, j]
        #步骤8：根据b_1和b_2更新b
        if (0 < oS.alphas[i]) and (oS.C > oS.alphas[i]):
            oS.b = b1
        elif (0 < oS.alphas[j]) and (oS.C > oS.alphas[j]):
            oS.b = b2
        else:
            oS.b = (b1 + b2) / 2.0
        return 1
    else:
        return 0


def smoP(dataMatIn, classLabels, C, toler, maxIter, kTup=('lin', 0)):
    """
    完整的线性SMO算法

    Args:
        dataMatIn: 数据矩阵
        classLabels: 数据标签
        C: 松弛变量
        toler: 容错率
        maxIter: 最大迭代次数
        kTup: 包含核函数信息的元组
    Returns:
        oS.b: SMO算法计算的b
        oS.alphas: SMO算法计算的alphas
    """
    oS = optStruct(np.mat(dataMatIn), np.mat(classLabels).transpose(), C, toler, kTup)  #初始化数据结构
    iter = 0  #初始化当前迭代次数
    entireSet = True
    alphaPairsChanged = 0
    while (iter < maxIter) and ((alphaPairsChanged > 0) or (entireSet)):  #遍历整个数据集都alpha也没有更新或者超过最大迭代次数,则退出循环
        alphaPairsChanged = 0
        if entireSet:  #遍历整个数据集
            for i in range(oS.m):
                alphaPairsChanged += innerL(i, oS)  #使用优化的SMO算法
                print("全样本遍历:第%d次迭代 样本:%d, alpha优化次数:%d" % (iter, i, alphaPairsChanged))
            iter += 1
        else:  #遍历非边界值
            nonBoundIs = np.nonzero((oS.alphas.A > 0) * (oS.alphas.A < C))[0]  #遍历不在边界0和C的alpha
            for i in nonBoundIs:
                alphaPairsChanged += innerL(i, oS)
                print("非边界遍历:第%d次迭代 样本:%d, alpha优化次数:%d" % (iter, i, alphaPairsChanged))
            iter += 1
        if entireSet:  #遍历一次后改为非边界遍历
            entireSet = False
        elif (alphaPairsChanged == 0):  #如果alpha没有更新,计算全样本遍历
            entireSet = True
        print("迭代次数: %d" % iter)
    return oS.b, oS.alphas

# %% [markdown]
# ## 【实验步骤】实现测试函数

# %% [markdown]
# 本节实现测试函数：

# %%
def testDigits(kTup=('rbf', 10)):
    """
    测试函数

    Args:
        kTup: 包含核函数信息的元组
    Returns:
        无
    """
    dataArr, labelArr = loadImages('svm_hand_digits/trainingDigits')
    b, alphas = smoP(dataArr, labelArr, 200, 0.0001, 10, kTup)
    datMat = np.mat(dataArr)
    labelMat = np.mat(labelArr).transpose()
    svInd = np.nonzero(alphas.A > 0)[0]
    sVs = datMat[svInd]
    labelSV = labelMat[svInd]
    print("支持向量个数:%d" % np.shape(sVs)[0])
    m, n = np.shape(datMat)
    errorCount = 0
    for i in range(m):
        kernelEval = kernelTrans(sVs, datMat[i, :], kTup)
        predict = kernelEval.T * np.multiply(labelSV, alphas[svInd]) + b
        if np.sign(predict) != np.sign(labelArr[i]): errorCount += 1
    print("训练集错误率: %.2f%%" % (float(errorCount) / m))
    dataArr, labelArr = loadImages('svm_hand_digits/testDigits')
    errorCount = 0
    datMat = np.mat(dataArr)
    labelMat = np.mat(labelArr).transpose()
    m, n = np.shape(datMat)
    for i in range(m):
        kernelEval = kernelTrans(sVs, datMat[i, :], kTup)
        predict = kernelEval.T * np.multiply(labelSV, alphas[svInd]) + b
        if np.sign(predict) != np.sign(labelArr[i]): errorCount += 1
    print("测试集错误率: %.2f%%" % (float(errorCount) / m))


if __name__ == '__main__':
    testDigits()
# Out:
# L==H
# 全样本遍历:第0次迭代 样本:0, alpha优化次数:0
# 全样本遍历:第0次迭代 样本:1, alpha优化次数:1
# 全样本遍历:第0次迭代 样本:2, alpha优化次数:2
# 全样本遍历:第0次迭代 样本:3, alpha优化次数:3
# 全样本遍历:第0次迭代 样本:4, alpha优化次数:4
# 全样本遍历:第0次迭代 样本:5, alpha优化次数:5
# L==H
# 全样本遍历:第0次迭代 样本:6, alpha优化次数:5
# 全样本遍历:第0次迭代 样本:7, alpha优化次数:6
# 全样本遍历:第0次迭代 样本:8, alpha优化次数:7
# 全样本遍历:第0次迭代 样本:9, alpha优化次数:8
# 全样本遍历:第0次迭代 样本:10, alpha优化次数:9
# L==H
# 全样本遍历:第0次迭代 样本:11, alpha优化次数:9
# 全样本遍历:第0次迭代 样本:12, alpha优化次数:10
# 全样本遍历:第0次迭代 样本:13, alpha优化次数:11
# 全样本遍历:第0次迭代 样本:14, alpha优化次数:12
# 全样本遍历:第0次迭代 样本:15, alpha优化次数:13
# 全样本遍历:第0次迭代 样本:16, alpha优化次数:14
# 全样本遍历:第0次迭代 样本:17, alpha优化次数:15
# 全样本遍历:第0次迭代 样本:18, alpha优化次数:16
# 全样本遍历:第0次迭代 样本:19, alpha优化次数:16
# 全样本遍历:第0次迭代 样本:20, alpha优化次数:17
# 全样本遍历:第0次迭代 样本:21, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:22, alpha优化次数:18
# 全样本遍历:第0次迭代 样本:23, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:24, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:25, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:26, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:27, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:28, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:29, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:30, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:31, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:32, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:33, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:34, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:35, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:36, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:37, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:38, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:39, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:40, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:41, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:42, alpha优化次数:18
# 全样本遍历:第0次迭代 样本:43, alpha优化次数:18
# 全样本遍历:第0次迭代 样本:44, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:45, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:46, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:47, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:48, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:49, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:50, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:51, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:52, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:53, alpha优化次数:18
# 全样本遍历:第0次迭代 样本:54, alpha优化次数:18
# 全样本遍历:第0次迭代 样本:55, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:56, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:57, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:58, alpha优化次数:18
# 全样本遍历:第0次迭代 样本:59, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:60, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:61, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:62, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:63, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:64, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:65, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:66, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:67, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:68, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:69, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:70, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:71, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:72, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:73, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:74, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:75, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:76, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:77, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:78, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:79, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:80, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:81, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:82, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:83, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:84, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:85, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:86, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:87, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:88, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:89, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:90, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:91, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:92, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:93, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:94, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:95, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:96, alpha优化次数:18
# 全样本遍历:第0次迭代 样本:97, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:98, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:99, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:100, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:101, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:102, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:103, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:104, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:105, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:106, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:107, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:108, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:109, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:110, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:111, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:112, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:113, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:114, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:115, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:116, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:117, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:118, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:119, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:120, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:121, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:122, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:123, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:124, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:125, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:126, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:127, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:128, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:129, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:130, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:131, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:132, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:133, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:134, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:135, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:136, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:137, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:138, alpha优化次数:18
# 全样本遍历:第0次迭代 样本:139, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:140, alpha优化次数:18
# 全样本遍历:第0次迭代 样本:141, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:142, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:143, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:144, alpha优化次数:18
# 全样本遍历:第0次迭代 样本:145, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:146, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:147, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:148, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:149, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:150, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:151, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:152, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:153, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:154, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:155, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:156, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:157, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:158, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:159, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:160, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:161, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:162, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:163, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:164, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:165, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:166, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:167, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:168, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:169, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:170, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:171, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:172, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:173, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:174, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:175, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:176, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:177, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:178, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:179, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:180, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:181, alpha优化次数:18
# 全样本遍历:第0次迭代 样本:182, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:183, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:184, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:185, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:186, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:187, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:188, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:189, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:190, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:191, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:192, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:193, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:194, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:195, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:196, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:197, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:198, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:199, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:200, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:201, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:202, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:203, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:204, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:205, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:206, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:207, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:208, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:209, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:210, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:211, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:212, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:213, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:214, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:215, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:216, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:217, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:218, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:219, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:220, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:221, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:222, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:223, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:224, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:225, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:226, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:227, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:228, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:229, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:230, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:231, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:232, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:233, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:234, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:235, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:236, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:237, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:238, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:239, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:240, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:241, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:242, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:243, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:244, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:245, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:246, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:247, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:248, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:249, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:250, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:251, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:252, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:253, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:254, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:255, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:256, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:257, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:258, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:259, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:260, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:261, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:262, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:263, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:264, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:265, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:266, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:267, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:268, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:269, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:270, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:271, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:272, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:273, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:274, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:275, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:276, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:277, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:278, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:279, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:280, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:281, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:282, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:283, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:284, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:285, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:286, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:287, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:288, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:289, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:290, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:291, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:292, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:293, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:294, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:295, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:296, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:297, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:298, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:299, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:300, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:301, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:302, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:303, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:304, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:305, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:306, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:307, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:308, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:309, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:310, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:311, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:312, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:313, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:314, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:315, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:316, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:317, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:318, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:319, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:320, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:321, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:322, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:323, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:324, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:325, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:326, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:327, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:328, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:329, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:330, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:331, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:332, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:333, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:334, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:335, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:336, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:337, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:338, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:339, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:340, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:341, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:342, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:343, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:344, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:345, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:346, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:347, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:348, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:349, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:350, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:351, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:352, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:353, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:354, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:355, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:356, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:357, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:358, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:359, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:360, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:361, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:362, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:363, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:364, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:365, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:366, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:367, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:368, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:369, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:370, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:371, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:372, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:373, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:374, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:375, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:376, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:377, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:378, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:379, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:380, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:381, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:382, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:383, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:384, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:385, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:386, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:387, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:388, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:389, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:390, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:391, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:392, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:393, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:394, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:395, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:396, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:397, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:398, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:399, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:400, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:401, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:402, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:403, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:404, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:405, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:406, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:407, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:408, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:409, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:410, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:411, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:412, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:413, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:414, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:415, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:416, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:417, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:418, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:419, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:420, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:421, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:422, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:423, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:424, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:425, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:426, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:427, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:428, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:429, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:430, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:431, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:432, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:433, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:434, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:435, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:436, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:437, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:438, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:439, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:440, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:441, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:442, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:443, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:444, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:445, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:446, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:447, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:448, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:449, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:450, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:451, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:452, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:453, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:454, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:455, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:456, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:457, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:458, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:459, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:460, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:461, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:462, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:463, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:464, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:465, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:466, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:467, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:468, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:469, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:470, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:471, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:472, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:473, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:474, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:475, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:476, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:477, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:478, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:479, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:480, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:481, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:482, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:483, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:484, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:485, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:486, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:487, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:488, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:489, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:490, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:491, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:492, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:493, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:494, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:495, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:496, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:497, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:498, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:499, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:500, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:501, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:502, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:503, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:504, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:505, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:506, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:507, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:508, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:509, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:510, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:511, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:512, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:513, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:514, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:515, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:516, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:517, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:518, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:519, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:520, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:521, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:522, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:523, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:524, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:525, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:526, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:527, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:528, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:529, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:530, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:531, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:532, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:533, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:534, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:535, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:536, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:537, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:538, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:539, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:540, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:541, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:542, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:543, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:544, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:545, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:546, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:547, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:548, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:549, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:550, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:551, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:552, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:553, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:554, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:555, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:556, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:557, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:558, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:559, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:560, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:561, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:562, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:563, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:564, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:565, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:566, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:567, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:568, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:569, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:570, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:571, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:572, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:573, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:574, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:575, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:576, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:577, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:578, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:579, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:580, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:581, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:582, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:583, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:584, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:585, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:586, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:587, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:588, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:589, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:590, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:591, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:592, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:593, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:594, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:595, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:596, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:597, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:598, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:599, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:600, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:601, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:602, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:603, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:604, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:605, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:606, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:607, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:608, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:609, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:610, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:611, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:612, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:613, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:614, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:615, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:616, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:617, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:618, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:619, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:620, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:621, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:622, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:623, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:624, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:625, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:626, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:627, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:628, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:629, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:630, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:631, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:632, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:633, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:634, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:635, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:636, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:637, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:638, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:639, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:640, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:641, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:642, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:643, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:644, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:645, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:646, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:647, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:648, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:649, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:650, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:651, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:652, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:653, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:654, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:655, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:656, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:657, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:658, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:659, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:660, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:661, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:662, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:663, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:664, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:665, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:666, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:667, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:668, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:669, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:670, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:671, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:672, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:673, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:674, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:675, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:676, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:677, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:678, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:679, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:680, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:681, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:682, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:683, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:684, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:685, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:686, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:687, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:688, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:689, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:690, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:691, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:692, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:693, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:694, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:695, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:696, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:697, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:698, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:699, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:700, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:701, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:702, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:703, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:704, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:705, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:706, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:707, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:708, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:709, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:710, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:711, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:712, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:713, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:714, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:715, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:716, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:717, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:718, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:719, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:720, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:721, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:722, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:723, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:724, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:725, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:726, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:727, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:728, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:729, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:730, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:731, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:732, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:733, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:734, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:735, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:736, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:737, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:738, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:739, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:740, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:741, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:742, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:743, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:744, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:745, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:746, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:747, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:748, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:749, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:750, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:751, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:752, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:753, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:754, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:755, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:756, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:757, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:758, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:759, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:760, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:761, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:762, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:763, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:764, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:765, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:766, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:767, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:768, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:769, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:770, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:771, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:772, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:773, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:774, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:775, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:776, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:777, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:778, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:779, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:780, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:781, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:782, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:783, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:784, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:785, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:786, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:787, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:788, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:789, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:790, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:791, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:792, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:793, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:794, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:795, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:796, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:797, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:798, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:799, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:800, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:801, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:802, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:803, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:804, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:805, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:806, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:807, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:808, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:809, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:810, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:811, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:812, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:813, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:814, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:815, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:816, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:817, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:818, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:819, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:820, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:821, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:822, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:823, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:824, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:825, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:826, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:827, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:828, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:829, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:830, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:831, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:832, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:833, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:834, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:835, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:836, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:837, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:838, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:839, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:840, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:841, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:842, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:843, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:844, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:845, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:846, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:847, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:848, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:849, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:850, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:851, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:852, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:853, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:854, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:855, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:856, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:857, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:858, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:859, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:860, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:861, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:862, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:863, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:864, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:865, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:866, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:867, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:868, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:869, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:870, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:871, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:872, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:873, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:874, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:875, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:876, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:877, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:878, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:879, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:880, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:881, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:882, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:883, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:884, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:885, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:886, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:887, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:888, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:889, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:890, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:891, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:892, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:893, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:894, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:895, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:896, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:897, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:898, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:899, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:900, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:901, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:902, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:903, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:904, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:905, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:906, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:907, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:908, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:909, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:910, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:911, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:912, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:913, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:914, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:915, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:916, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:917, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:918, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:919, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:920, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:921, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:922, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:923, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:924, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:925, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:926, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:927, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:928, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:929, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:930, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:931, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:932, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:933, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:934, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:935, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:936, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:937, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:938, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:939, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:940, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:941, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:942, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:943, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:944, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:945, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:946, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:947, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:948, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:949, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:950, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:951, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:952, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:953, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:954, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:955, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:956, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:957, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:958, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:959, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:960, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:961, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:962, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:963, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:964, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:965, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:966, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:967, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:968, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:969, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:970, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:971, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:972, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:973, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:974, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:975, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:976, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:977, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:978, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:979, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:980, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:981, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:982, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:983, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:984, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:985, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:986, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:987, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:988, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:989, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:990, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:991, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:992, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:993, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:994, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:995, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:996, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:997, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:998, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:999, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1000, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1001, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1002, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1003, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1004, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1005, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1006, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1007, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1008, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1009, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1010, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1011, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1012, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1013, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1014, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1015, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1016, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1017, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1018, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1019, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1020, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1021, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1022, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1023, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1024, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1025, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1026, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1027, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1028, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1029, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1030, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1031, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1032, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1033, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1034, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1035, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1036, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1037, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1038, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1039, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1040, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1041, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1042, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1043, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1044, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1045, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1046, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1047, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1048, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1049, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1050, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1051, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1052, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1053, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1054, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1055, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1056, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1057, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1058, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1059, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1060, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1061, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1062, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1063, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1064, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1065, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1066, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1067, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1068, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1069, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1070, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1071, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1072, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1073, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1074, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1075, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1076, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1077, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1078, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1079, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1080, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1081, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1082, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1083, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1084, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1085, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1086, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1087, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1088, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1089, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1090, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1091, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1092, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1093, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1094, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1095, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1096, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1097, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1098, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1099, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1100, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1101, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1102, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1103, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1104, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1105, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1106, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1107, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1108, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1109, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1110, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1111, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1112, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1113, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1114, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1115, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1116, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1117, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1118, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1119, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1120, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1121, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1122, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1123, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1124, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1125, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1126, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1127, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1128, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1129, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1130, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1131, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1132, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1133, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1134, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1135, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1136, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1137, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1138, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1139, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1140, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1141, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1142, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1143, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1144, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1145, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1146, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1147, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1148, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1149, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1150, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1151, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1152, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1153, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1154, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1155, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1156, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1157, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1158, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1159, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1160, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1161, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1162, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1163, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1164, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1165, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1166, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1167, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1168, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1169, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1170, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1171, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1172, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1173, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1174, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1175, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1176, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1177, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1178, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1179, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1180, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1181, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1182, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1183, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1184, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1185, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1186, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1187, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1188, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1189, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1190, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1191, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1192, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1193, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1194, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1195, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1196, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1197, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1198, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1199, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1200, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1201, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1202, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1203, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1204, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1205, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1206, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1207, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1208, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1209, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1210, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1211, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1212, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1213, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1214, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1215, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1216, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1217, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1218, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1219, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1220, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1221, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1222, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1223, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1224, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1225, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1226, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1227, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1228, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1229, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1230, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1231, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1232, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1233, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1234, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1235, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1236, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1237, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1238, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1239, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1240, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1241, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1242, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1243, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1244, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1245, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1246, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1247, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1248, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1249, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1250, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1251, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1252, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1253, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1254, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1255, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1256, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1257, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1258, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1259, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1260, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1261, alpha优化次数:18
# L==H
# 全样本遍历:第0次迭代 样本:1262, alpha优化次数:18
# L==H
# ...
# 全样本遍历:第3次迭代 样本:1532, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1533, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1534, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1535, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1536, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1537, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1538, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1539, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1540, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1541, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1542, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1543, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1544, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1545, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1546, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1547, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1548, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1549, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1550, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1551, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1552, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1553, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1554, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1555, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1556, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1557, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1558, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1559, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1560, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1561, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1562, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1563, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1564, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1565, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1566, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1567, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1568, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1569, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1570, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1571, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1572, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1573, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1574, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1575, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1576, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1577, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1578, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1579, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1580, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1581, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1582, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1583, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1584, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1585, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1586, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1587, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1588, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1589, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1590, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1591, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1592, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1593, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1594, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1595, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1596, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1597, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1598, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1599, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1600, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1601, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1602, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1603, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1604, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1605, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1606, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1607, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1608, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1609, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1610, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1611, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1612, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1613, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1614, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1615, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1616, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1617, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1618, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1619, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1620, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1621, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1622, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1623, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1624, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1625, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1626, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1627, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1628, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1629, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1630, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1631, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1632, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1633, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1634, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1635, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1636, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1637, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1638, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1639, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1640, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1641, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1642, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1643, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1644, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1645, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1646, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1647, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1648, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1649, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1650, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1651, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1652, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1653, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1654, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1655, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1656, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1657, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1658, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1659, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1660, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1661, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1662, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1663, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1664, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1665, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1666, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1667, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1668, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1669, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1670, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1671, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1672, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1673, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1674, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1675, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1676, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1677, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1678, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1679, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1680, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1681, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1682, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1683, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1684, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1685, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1686, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1687, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1688, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1689, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1690, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1691, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1692, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1693, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1694, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1695, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1696, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1697, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1698, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1699, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1700, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1701, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1702, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1703, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1704, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1705, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1706, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1707, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1708, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1709, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1710, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1711, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1712, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1713, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1714, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1715, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1716, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1717, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1718, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1719, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1720, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1721, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1722, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1723, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1724, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1725, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1726, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1727, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1728, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1729, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1730, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1731, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1732, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1733, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1734, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1735, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1736, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1737, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1738, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1739, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1740, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1741, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1742, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1743, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1744, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1745, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1746, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1747, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1748, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1749, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1750, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1751, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1752, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1753, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1754, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1755, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1756, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1757, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1758, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1759, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1760, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1761, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1762, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1763, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1764, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1765, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1766, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1767, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1768, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1769, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1770, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1771, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1772, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1773, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1774, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1775, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1776, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1777, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1778, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1779, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1780, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1781, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1782, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1783, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1784, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1785, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1786, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1787, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1788, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1789, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1790, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1791, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1792, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1793, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1794, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1795, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1796, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1797, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1798, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1799, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1800, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1801, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1802, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1803, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1804, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1805, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1806, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1807, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1808, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1809, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1810, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1811, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1812, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1813, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1814, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1815, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1816, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1817, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1818, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1819, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1820, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1821, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1822, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1823, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1824, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1825, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1826, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1827, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1828, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1829, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1830, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1831, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1832, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1833, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1834, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1835, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1836, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1837, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1838, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1839, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1840, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1841, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1842, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1843, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1844, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1845, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1846, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1847, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1848, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1849, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1850, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1851, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1852, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1853, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1854, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1855, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1856, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1857, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1858, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1859, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1860, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1861, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1862, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1863, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1864, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1865, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1866, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1867, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1868, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1869, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1870, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1871, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1872, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1873, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1874, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1875, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1876, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1877, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1878, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1879, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1880, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1881, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1882, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1883, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1884, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1885, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1886, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1887, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1888, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1889, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1890, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1891, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1892, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1893, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1894, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1895, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1896, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1897, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1898, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1899, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1900, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1901, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1902, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1903, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1904, alpha优化次数:0
# L==H
# 全样本遍历:第3次迭代 样本:1905, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1906, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1907, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1908, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1909, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1910, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1911, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1912, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1913, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1914, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1915, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1916, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1917, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1918, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1919, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1920, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1921, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1922, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1923, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1924, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1925, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1926, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1927, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1928, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1929, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1930, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1931, alpha优化次数:0
# 全样本遍历:第3次迭代 样本:1932, alpha优化次数:0
# alpha_j变化太小
# 全样本遍历:第3次迭代 样本:1933, alpha优化次数:0
# 迭代次数: 4
# 支持向量个数:299
# 训练集错误率: 0.00%
# 测试集错误率: 0.01%

# %% [markdown]
# 本代码中，SMO算法实现部分和实验《SVM支持向量机原理》中介绍的算法是一样的，这里新创建了img2vector()、loadImages()、testDigits()函数，它们分别用于二进制图形转换、图片加载、训练SVM分类器。
# SVM分类器是个二类分类器，所以在设置标签的时候，将9作为负类，其余的0-8作为正类，进行训练。这是一种'ovr'思想，即one vs rest，就是对一个类别和剩余所有的类别进行分类。如果想实现10个数字的识别，一个简单的方法是，训练出10个分类器。这里简单起见，只训练了一个用于分类9和其余所有数字的分类器。
# 可以看到，虽然我们进行了所谓的"优化"，但是训练仍然很耗时，迭代4次，花费了大量的时间（5~10分钟左右）。因为我们没有多进程、没有设置自动的终止条件，总之需要优化的地方太多了。尽管如此，我们训练后得到的结果还是不错的，可以看到训练集错误率为0，测试集错误率也仅为0.01%。
# 具体有哪些优化方法呢？同学们可以尝试修改kTup参数来查看测试集错误率和训练集错误率，支持向量个数的变化。

# %% [markdown]
# ## 【实验步骤】scikit-learn的SVM说明

# %% [markdown]
# sklearn.svm模块提供了很多模型供我们使用，本文使用的是svm.SVC，它是基于libsvm实现的。
# ![](svm_hand_digits/1_svm_hand_digits.png)
# 让我们先看下SVC这个函数，一共有14个参数:
# ![](svm_hand_digits/2_svm_hand_digits.png)
# 参数说明如下：
# * C：惩罚项，float类型，可选参数，默认为1.0，C越大，即对分错样本的惩罚程度越大，因此在训练样本中准确率越高，但是泛化能力降低，也就是对测试数据的分类准确率降低。相反，减小C的话，容许训练样本中有一些误分类错误样本，泛化能力强。对于训练样本带有噪声的情况，一般采用后者，把训练样本集中错误分类的样本作为噪声。
# 　kernel：核函数类型，str类型，默认为'rbf'。可选参数为：
#         * 'linear'：线性核函数
#         * 'poly'：多项式核函数
#         * 'rbf'：径像核函数/高斯核
#         * 'sigmod'：sigmod核函数
#         * 'precomputed'：核矩阵
#         * precomputed表示自己提前计算好核函数矩阵，这时候算法内部就不再用核函数去计算核矩阵，而是直接用你给的核矩阵，核矩阵需要为n*n的。
# * degree：多项式核函数的阶数，int类型，可选参数，默认为3。这个参数只对多项式核函数有用，是指多项式核函数的阶数n，如果给的核函数参数是其他核函数，则会自动忽略该参数。
# * gamma：核函数系数，float类型，可选参数，默认为auto。只对'rbf' ,'poly' ,'sigmod'有效。如果gamma为auto，代表其值为样本特征数的倒数，即1/n_features。
# * coef0：核函数中的独立项，float类型，可选参数，默认为0.0。只有对'poly' 和,'sigmod'核函数有用，是指其中的参数c。
# * probability：是否启用概率估计，bool类型，可选参数，默认为False，这必须在调用fit()之前启用，并且会fit()方法速度变慢。
# * shrinking：是否采用启发式收缩方式，bool类型，可选参数，默认为True。
# * tol：svm停止训练的误差精度，float类型，可选参数，默认为1e^-3。
# * cache_size：内存大小，float类型，可选参数，默认为200。指定训练所需要的内存，以MB为单位，默认为200MB。
# * class_weight：类别权重，dict类型或str类型，可选参数，默认为None。给每个类别分别设置不同的惩罚参数C，如果没有给，则会给所有类别都给C=1，即前面参数指出的参数C。如果给定参数'balance'，则使用y的值自动调整与输入数据中的类频率成反比的权重。
# * verbose：是否启用详细输出，bool类型，默认为False，此设置利用libsvm中的每个进程运行时设置，如果启用，可能无法在多线程上下文中正常工作。一般情况都设为False，不用管它。
# * max_iter：最大迭代次数，int类型，默认为-1，表示不限制。
# * decision_function_shape：决策函数类型，可选参数'ovo'和'ovr'，默认为'ovr'。'ovo'表示one vs one，'ovr'表示one vs rest。
# * random_state：数据洗牌时的种子值，int类型，可选参数，默认为None。伪随机数发生器的种子,在混洗数据时用于概率估计。
#
# 由于在上一个实验中，我们自己动手实现过SVM，所以每个参数的意思，你应该大概都能明白的。

# %% [markdown]
# ## 【练习】基于scikit-learn构建SVM

# %% [markdown]
# SVC很强大，我们不用理解算法实现的具体细节，不用理解算法的优化方法。同时，它也满足我们的多分类需求。

# %%
from os import listdir

# -*- coding: UTF-8 -*-
import numpy as np
from sklearn.svm import SVC


def img2vector(filename):
    """
    将32x32的二进制图像转换为1x1024向量。

    Args:
        filename: 文件名
    Returns:
        returnVect: 返回的二进制图像的1x1024向量
    """
    #创建1x1024零向量
    returnVect = np.zeros((1, 1024))
    #打开文件
    fr = open(filename)
    #按行读取
    for i in range(32):
        #读一行数据
        lineStr = fr.readline()
        #每一行的前32个元素依次添加到returnVect中
        for j in range(32):
            returnVect[0, 32 * i + j] = int(lineStr[j])
    #返回转换后的1x1024向量
    return returnVect


def handwritingClassTest():
    """
    手写数字分类测试

    Returns:
        无
    """
    #测试集的Labels
    hwLabels = []
    #返回trainingDigits目录下的文件名
    trainingFileList = listdir('svm_hand_digits/trainingDigits')
    #返回文件夹下文件的个数
    m = len(trainingFileList)
    #初始化训练的Mat矩阵,测试集
    trainingMat = np.zeros((m, 1024))
    #从文件名中解析出训练集的类别
    for i in range(m):
        #获得文件的名字
        fileNameStr = trainingFileList[i]
        #获得分类的数字
        classNumber = int(fileNameStr.split('_')[0])
        #将获得的类别添加到hwLabels中
        hwLabels.append(classNumber)
        #将每一个文件的1x1024数据存储到trainingMat矩阵中
        trainingMat[i, :] = img2vector('svm_hand_digits/trainingDigits/%s' % (fileNameStr))

    clf = SVC(C=300, kernel='rbf', gamma='auto', coef0=0.1)  # 创建SVC对象
    clf.fit(trainingMat, hwLabels)  #调用fit函数进行模型训练

    #返回testDigits目录下的文件列表
    testFileList = listdir('svm_hand_digits/testDigits')
    #错误检测计数
    errorCount = 0.0
    #测试数据的数量
    mTest = len(testFileList)
    #从文件中解析出测试集的类别并进行分类测试
    for i in range(mTest):
        #获得文件的名字
        fileNameStr = testFileList[i]
        #获得分类的数字
        classNumber = int(fileNameStr.split('_')[0])
        #获得测试集的1x1024向量,用于训练
        vectorUnderTest = img2vector('svm_hand_digits/testDigits/%s' % (fileNameStr))
        #获得预测结果
        # classifierResult = classify0(vectorUnderTest, trainingMat, hwLabels, 3)
        classifierResult = clf.predict(vectorUnderTest)
        print("分类返回结果为%d\t真实结果为%d" % (classifierResult, classNumber))
        if (classifierResult != classNumber):
            errorCount += 1.0
    print("总共错了%d个数据\n错误率为%f%%" % (errorCount, errorCount / mTest * 100))


if __name__ == '__main__':
    handwritingClassTest()
# Out:
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为0	真实结果为0
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为7	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为1	真实结果为1
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为2	真实结果为2
# 分类返回结果为9	真实结果为2
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为9	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为5	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为9	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为5	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为9	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为3	真实结果为3
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为4	真实结果为4
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为5	真实结果为5
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为4	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为6	真实结果为6
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为4	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为7	真实结果为7
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为6	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为1	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为8	真实结果为8
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为1	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为3	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 分类返回结果为9	真实结果为9
# 总共错了13个数据
# 错误率为1.374207%

# %% [markdown]
# 可以看到测试集的错误率仅为1.37%。试着改变SVC的参数，慢慢体会一下吧~

# %% [markdown]
# ## 实验总结

# %% [markdown]
# 通过本实验，您应该能达到以下两个目标：
# 1. 掌握SVM算法原理。
# 2. 熟悉SVM算法的初步应用。

# %% [markdown]
# ##  参考文献及延伸阅读

# %% [markdown]
# ### 参考资料：
# * 1.哈林顿，李锐. 机器学习实战 : Machine learning in action[M]. 人民邮电出版社, 2013.
# * 2.http://cuijiahua.com/blog/2017/11/ml_8_svm_1.html
#
# ### 延伸阅读：
# * 1.李航. 统计学习方法[M]. 清华大学出版社, 2012.
